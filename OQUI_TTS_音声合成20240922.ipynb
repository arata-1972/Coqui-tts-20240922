# %%
import os


# 作業ディレクトリを設定
in_path = '/home/shogo/デスクトップ/Coqui-tts-20240922/'
os.chdir(in_path)

# 作業ディレクトリをTTSに変更
os.chdir(os.path.join(in_path, "coqui-ai-TTS/TTS"))
# %env CUDA_VISIBLE_DEVICES=0
# !python train.py
# Out:
# env: CUDA_VISIBLE_DEVICES=0
# ここにきた2 nan_tw_phonemizer
# ここにきた1 NAN_TW_Phonemizer initialized
# ここにきた2 nan_tw_phonemizer
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_characters', 'add_blank', 'blank_id', 'characters', 'decode', 'encode', 'ids_to_text', 'init_from_config', 'intersperse_blank_char', 'not_found_characters', 'pad_id', 'pad_with_bos_eos', 'phonemizer', 'print_logs', 'text_cleaner', 'text_to_ids', 'use_eos_bos', 'use_phonemes']
# File not found, skipping: /home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/wavs/9c16b952-19db-4d60-a646-93729dcc3ad2.wav
# File not found, skipping: /home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/wavs/ee63bc1d-3657-46d6-b7c5-edfbdf4084a1.wav
# ef3f7966-7b7a-47e9-a11c-bfa88f531ce7|伊講你是一蕊花，這是一个比喻。|伊講你是一蕊花 這是一个比喻
#
# b828bd6e-101c-4d8b-8358-2f0eebe7a31e|山頂一蕊花，毋值平洋一枝草。|山頂一蕊花 毋值平洋一枝草
#
# bcc8282c-bedc-4707-8713-aec5c467a79e|這塊枋仔欲雕一蕊花。|這塊枋仔欲雕一蕊花
#
# 90e2c93f-71c0-4f98-b14a-30e1a23d3472|一蕊花|一蕊花
#
# 50d95462-9aff-4522-8170-1e506c72f1ac|紅嬰仔哭甲一身軀汗。|紅嬰仔哭甲一身軀汗
#
# a3799a4c-18ac-46df-b784-b0503447f830|阿明共退休金攏提去炒股票，想欲一睏仔就好額，到尾煞倒了錢，莫怪俗語講：「欲好額等後世，欲做官學做戲」。|阿明共退休金攏提去炒股票 想欲一睏仔就好額 到尾煞倒了錢 莫怪俗語講 欲好額等後世 欲做官學做戲
#
# 164beb41-9b7e-4718-ba54-1fe67c120ad7|伊跤手真緊，穡頭一睏仔就做了矣。|伊跤手真緊 穡頭一睏仔就做了矣
#
# a115db03-ca1f-42ca-8017-f9f787c5d476|伊做代誌真猛掠，一睏仔就做好矣。|伊做代誌真猛掠 一睏仔就做好矣
#
# 5c40f24f-f741-4b2b-a5c5-a66a825fb8be|遮的物件伊做一睏仔共伊食了。|遮的物件伊做一睏仔共伊食了
#
# adbd90cf-2e9e-47c2-8c8f-400090397a53|一睏仔|一睏仔
#
# Train Samples: [{'text': '落伍\n', 'audio_file': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/wavs/5ab5804c-b3af-44ba-b60c-95c58c89e36c.wav', 'speaker_name': 'ljspeech', 'root_path': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/', 'language': '', 'audio_unique_name': '#wavs/5ab5804c-b3af-44ba-b60c-95c58c89e36c', 'audio': array([0., 0., 0., ..., 0., 0., 0.])}, {'text': '男子漢\n', 'audio_file': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/wavs/ee2eb8ee-1131-44cc-ac38-9aef82be9564.wav', 'speaker_name': 'ljspeech', 'root_path': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/', 'language': '', 'audio_unique_name': '#wavs/ee2eb8ee-1131-44cc-ac38-9aef82be9564', 'audio': array([0., 0., 0., ..., 0., 0., 0.])}, {'text': '鬥榫\n', 'audio_file': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/wavs/db4bd246-00f2-4b58-9778-2db54adef129.wav', 'speaker_name': 'ljspeech', 'root_path': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/', 'language': '', 'audio_unique_name': '#wavs/db4bd246-00f2-4b58-9778-2db54adef129', 'audio': array([0., 0., 0., ..., 0., 0., 0.])}, {'text': '日鬚\n', 'audio_file': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/wavs/63e1fb8b-4e84-41d4-8022-0556aaee929f.wav', 'speaker_name': 'ljspeech', 'root_path': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/', 'language': '', 'audio_unique_name': '#wavs/63e1fb8b-4e84-41d4-8022-0556aaee929f', 'audio': array([0., 0., 0., ..., 0., 0., 0.])}, {'text': '伊的志願是欲做醫生\n', 'audio_file': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/wavs/cbcb3f8e-1e25-4cad-b7df-b17bde6641e8.wav', 'speaker_name': 'ljspeech', 'root_path': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/', 'language': '', 'audio_unique_name': '#wavs/cbcb3f8e-1e25-4cad-b7df-b17bde6641e8', 'audio': array([0., 0., 0., ..., 0., 0., 0.])}]
# Eval Samples: [{'text': '塌落來\n', 'audio_file': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/wavs/09d92121-8d06-4649-9e41-4e5abeedfef4.wav', 'speaker_name': 'ljspeech', 'root_path': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/', 'language': '', 'audio_unique_name': '#wavs/09d92121-8d06-4649-9e41-4e5abeedfef4', 'audio': array([0., 0., 0., ..., 0., 0., 0.])}, {'text': '伊欲出門去做工 煞臨時接著電話 行袂開跤\n', 'audio_file': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/wavs/fa45e2a1-4965-4b75-87c8-99591fb646d5.wav', 'speaker_name': 'ljspeech', 'root_path': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/', 'language': '', 'audio_unique_name': '#wavs/fa45e2a1-4965-4b75-87c8-99591fb646d5', 'audio': array([0., 0., 0., ..., 0., 0., 0.])}, {'text': '光明的前途\n', 'audio_file': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/wavs/d4589d20-8b6d-4fb8-a49e-5d58383ae31b.wav', 'speaker_name': 'ljspeech', 'root_path': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/', 'language': '', 'audio_unique_name': '#wavs/d4589d20-8b6d-4fb8-a49e-5d58383ae31b', 'audio': array([0., 0., 0., ..., 0., 0., 0.])}, {'text': '青苔仔是一種細隻鳥仔 佇都市的公園抑是學校攏看會著伊的影跡\n', 'audio_file': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/wavs/ac7dda2d-7490-4e01-9395-bc4ed74593d7.wav', 'speaker_name': 'ljspeech', 'root_path': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/', 'language': '', 'audio_unique_name': '#wavs/ac7dda2d-7490-4e01-9395-bc4ed74593d7', 'audio': array([-0.00137329, -0.0015564 , -0.00161743, ..., -0.00708008,
#        -0.00714111, -0.00738525])}, {'text': '紮禮物送伊\n', 'audio_file': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/wavs/6937d6b4-621d-4538-9e0c-38412a8d9ac3.wav', 'speaker_name': 'ljspeech', 'root_path': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/', 'language': '', 'audio_unique_name': '#wavs/6937d6b4-621d-4538-9e0c-38412a8d9ac3', 'audio': array([-2.13623047e-04, -1.83105469e-04, -1.22070312e-04, ...,
#        -3.05175781e-05, -9.15527344e-05, -9.15527344e-05])}]
# トレーニングサンプル数: 21911
# 評価サンプル数: 3867
#  > Training Environment:
#  | > Backend: Torch
#  | > Mixed precision: True
#  | > Precision: fp16
#  | > Current device: 0
#  | > Num. of GPUs: 1
#  | > Num. of CPUs: 24
#  | > Num. of Torch Threads: 16
#  | > Torch seed: 54321
#  | > Torch CUDNN: True
#  | > Torch CUDNN deterministic: False
#  | > Torch CUDNN benchmark: False
#  | > Torch TF32 MatMul: False
#  > Start Tensorboard: tensorboard --logdir=/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/vits_ljspeech-September-29-2024_06+33AM-63c3510
# /home/shogo/.local/lib/python3.11/site-packages/trainer/trainer.py:331: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler()
#
#  > Model has 83875180 parameters
#
#  > EPOCH: 0/1000
#  --> /home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/vits_ljspeech-September-29-2024_06+33AM-63c3510
# ここにきた2 nan_tw_phonemizer
#
#  > TRAINING (2024-09-29 06:34:03)
# /home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/tts/models/vits.py:1280: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=False):  # use float32 for the criterion
# /home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/tts/models/vits.py:1291: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=False):
# /home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/tts/models/vits.py:1318: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=False):  # use float32 for the criterion
#
#    --> TIME: 2024-09-29 06:34:09 -- STEP: 0/5478 -- GLOBAL_STEP: 0
#      | > loss_disc: 5.993553161621094  (5.993553161621094)
#      | > loss_disc_real_0: 1.0334289073944092  (1.0334289073944092)
#      | > loss_disc_real_1: 0.9634205102920532  (0.9634205102920532)
#      | > loss_disc_real_2: 0.9599868655204773  (0.9599868655204773)
#      | > loss_disc_real_3: 0.9852491617202759  (0.9852491617202759)
#      | > loss_disc_real_4: 1.0218586921691895  (1.0218586921691895)
#      | > loss_disc_real_5: 1.0281850099563599  (1.0281850099563599)
#      | > loss_0: 5.993553161621094  (5.993553161621094)
#      | > grad_norm_0: 0  (0)
#      | > loss_gen: 5.99077033996582  (5.99077033996582)
#      | > loss_kl: 288.7856140136719  (288.7856140136719)
#      | > loss_feat: 0.743730902671814  (0.743730902671814)
#      | > loss_mel: 143.5510711669922  (143.5510711669922)
#      | > loss_duration: 4.316463947296143  (4.316463947296143)
#      | > amp_scaler: 32768.0  (32768.0)
#      | > loss_1: 443.3876953125  (443.3876953125)
#      | > grad_norm_1: 0  (0)
#      | > current_lr_0: 0.0002
#      | > current_lr_1: 0.0002
#      | > step_time: 2.8088  (2.8088126182556152)
#      | > loader_time: 3.3436  (3.3436107635498047)
#
#
#    --> TIME: 2024-09-29 06:34:15 -- STEP: 25/5478 -- GLOBAL_STEP: 25
#      | > loss_disc: 2.49859356880188  (3.070435724258423)
#      | > loss_disc_real_0: 0.2712024748325348  (0.33465027421712873)
#      | > loss_disc_real_1: 0.20810429751873016  (0.30649702921509736)
#      | > loss_disc_real_2: 0.1816810965538025  (0.32693304181098937)
#      | > loss_disc_real_3: 0.276809424161911  (0.33880004674196246)
#      | > loss_disc_real_4: 0.20107264816761017  (0.3361536130309105)
#      | > loss_disc_real_5: 0.19762252271175385  (0.36002018213272097)
#      | > loss_0: 2.49859356880188  (3.070435724258423)
#      | > grad_norm_0: tensor(2.7025, device='cuda:0')  (tensor(5.0063, device='cuda:0'))
#      | > loss_gen: 2.1591994762420654  (2.329035785198211)
#      | > loss_kl: 20.205413818359375  (106.35600929260254)
#      | > loss_feat: 2.336594343185425  (2.362088298797607)
#      | > loss_mel: 47.605186462402344  (93.4805908203125)
#      | > loss_duration: 3.6217784881591797  (3.7757932853698732)
#      | > amp_scaler: 256.0  (1648.64)
#      | > loss_1: 75.92817687988281  (208.30351623535157)
#      | > grad_norm_1: tensor(219.8096, device='cuda:0')  (tensor(324.8196, device='cuda:0'))
#      | > current_lr_0: 0.0002
#      | > current_lr_1: 0.0002
#      | > step_time: 0.1579  (0.19139873504638671)
#      | > loader_time: 0.0013  (0.005113277435302733)
#
# テキスト===      相攬
# セパレーター===
#
#    --> TIME: 2024-09-29 06:34:18 -- STEP: 50/5478 -- GLOBAL_STEP: 50
#      | > loss_disc: 3.1370108127593994  (2.7771358776092536)
#      | > loss_disc_real_0: 0.30964574217796326  (0.2841294068098068)
#      | > loss_disc_real_1: 0.31590452790260315  (0.2928937993198632)
#      | > loss_disc_real_2: 0.3540651500225067  (0.29360702395439153)
#      | > loss_disc_real_3: 0.4762217700481415  (0.30259282484650607)
#      | > loss_disc_real_4: 0.3859027922153473  (0.3035877488553524)
#      | > loss_disc_real_5: 0.42731696367263794  (0.30775094896554944)
#      | > loss_0: 3.1370108127593994  (2.7771358776092536)
#      | > grad_norm_0: tensor(5.1105, device='cuda:0')  (tensor(4.9596, device='cuda:0'))
#      | > loss_gen: 2.187993288040161  (2.3310012972354897)
#      | > loss_kl: 7.783690452575684  (58.831749267578104)
#      | > loss_feat: 0.3086438775062561  (2.9276072227954857)
#      | > loss_mel: 63.11075973510742  (76.04014068603516)
#      | > loss_duration: 3.1877171993255615  (3.5818693017959595)
#      | > amp_scaler: 256.0  (952.3199999999997)
#      | > loss_1: 76.57880401611328  (143.7123664093017)
#      | > grad_norm_1: tensor(153.0199, device='cuda:0')  (tensor(270.2138, device='cuda:0'))
#      | > current_lr_0: 0.0002
#      | > current_lr_1: 0.0002
#      | > step_time: 0.1459  (0.16864864826202391)
#      | > loader_time: 0.0017  (0.003331894874572753)
#
# API response text: sio1 lam2
# pinyins_flat_list-  ['sio1', ' ', 'lam2']
# token - sio1
# pinyin- sio
# shisei- 1
# onso- ɕio
# これで学習はされていると想定
# onso to shisei - ɕio1
# token -
# token - lam2
# pinyin- lam
# shisei- 2
# onso- lam
# これで学習はされていると想定
# onso to shisei - lam2
# results- ɕio1 lam2
# 結果 =  ɕio1 lam2
#
#    --> TIME: 2024-09-29 06:34:22 -- STEP: 75/5478 -- GLOBAL_STEP: 75
#      | > loss_disc: 2.008840322494507  (2.6388561487197872)
#      | > loss_disc_real_0: 0.14357689023017883  (0.2538336271047592)
#      | > loss_disc_real_1: 0.16327384114265442  (0.28445358559489237)
#      | > loss_disc_real_2: 0.1687975972890854  (0.2821028661727905)
#      | > loss_disc_real_3: 0.1735626459121704  (0.2876384052634239)
#      | > loss_disc_real_4: 0.1422109156847  (0.292457154194514)
#      | > loss_disc_real_5: 0.12487074732780457  (0.28903832872708635)
#      | > loss_0: 2.008840322494507  (2.6388561487197872)
#      | > grad_norm_0: tensor(7.8692, device='cuda:0')  (tensor(4.9985, device='cuda:0'))
#      | > loss_gen: 2.7156553268432617  (2.380971345106762)
#      | > loss_kl: 5.3640923500061035  (41.4284740447998)
#      | > loss_feat: 5.552360534667969  (3.3421998953819276)
#      | > loss_mel: 50.057857513427734  (67.81272954305012)
#      | > loss_duration: 3.2252063751220703  (3.5224310175577798)
#      | > amp_scaler: 256.0  (720.213333333333)
#      | > loss_1: 66.91517639160156  (118.48680552164709)
#      | > grad_norm_1: tensor(200.5495, device='cuda:0')  (tensor(240.7287, device='cuda:0'))
#      | > current_lr_0: 0.0002
#      | > current_lr_1: 0.0002
#      | > step_time: 0.1458  (0.16109194755554196)
#      | > loader_time: 0.0015  (0.002694819768269856)
#
#
#    --> TIME: 2024-09-29 06:34:26 -- STEP: 100/5478 -- GLOBAL_STEP: 100
#      | > loss_disc: 1.9108502864837646  (2.5565180981159217)
#      | > loss_disc_real_0: 0.1035240963101387  (0.22771654259413482)
#      | > loss_disc_real_1: 0.21603180468082428  (0.2758412547782061)
#      | > loss_disc_real_2: 0.23252300918102264  (0.27608656279742705)
#      | > loss_disc_real_3: 0.23725692927837372  (0.28176690660417075)
#      | > loss_disc_real_4: 0.20216797292232513  (0.28032771259546274)
#      | > loss_disc_real_5: 0.12750543653964996  (0.2669268689304591)
#      | > loss_0: 1.9108502864837646  (2.5565180981159217)
#      | > grad_norm_0: tensor(2.7442, device='cuda:0')  (tensor(4.7596, device='cuda:0'))
#      | > loss_gen: 2.988321304321289  (2.4038970631361023)
#      | > loss_kl: 5.109047889709473  (32.284224858284)
#      | > loss_feat: 4.6828742027282715  (3.467945126891136)
#      | > loss_mel: 52.768165588378906  (63.11648181915282)
#      | > loss_duration: 3.4232025146484375  (3.45702517747879)
#      | > amp_scaler: 256.0  (604.1600000000001)
#      | > loss_1: 68.97161102294922  (104.72957370758053)
#      | > grad_norm_1: tensor(139.4023, device='cuda:0')  (tensor(220.1549, device='cuda:0'))
#      | > current_lr_0: 0.0002
#      | > current_lr_1: 0.0002
#      | > step_time: 0.1457  (0.1587335348129273)
#      | > loader_time: 0.0016  (0.0023877835273742685)
#
#
#    --> TIME: 2024-09-29 06:34:30 -- STEP: 125/5478 -- GLOBAL_STEP: 125
#      | > loss_disc: 2.188566207885742  (2.4687130742073062)
#      | > loss_disc_real_0: 0.06099875271320343  (0.20496691355109214)
#      | > loss_disc_real_1: 0.3963938057422638  (0.2719155537784096)
#      | > loss_disc_real_2: 0.3104093670845032  (0.2703858193159102)
#      | > loss_disc_real_3: 0.33475029468536377  (0.2751060289740562)
#      | > loss_disc_real_4: 0.3637241721153259  (0.2742121892273425)
#      | > loss_disc_real_5: 0.23978471755981445  (0.24837646269798272)
#      | > loss_0: 2.188566207885742  (2.4687130742073062)
#      | > grad_norm_0: tensor(5.3381, device='cuda:0')  (tensor(4.7606, device='cuda:0'))
#      | > loss_gen: 3.465392589569092  (2.5047280354499826)
#      | > loss_kl: 4.163369178771973  (26.659553190231325)
#      | > loss_feat: 5.181041240692139  (3.819336092710495)
#      | > loss_mel: 44.10188293457031  (59.71302807617186)
#      | > loss_duration: 2.8871850967407227  (3.4317657375335693)
#      | > amp_scaler: 256.0  (534.5279999999999)
#      | > loss_1: 59.79887008666992  (96.128410949707)
#      | > grad_norm_1: tensor(120.7733, device='cuda:0')  (tensor(207.4921, device='cuda:0'))
#      | > current_lr_0: 0.0002
#      | > current_lr_1: 0.0002
#      | > step_time: 0.1439  (0.1567436561584473)
#      | > loader_time: 0.0018  (0.0022212066650390636)
#
#
#    --> TIME: 2024-09-29 06:34:34 -- STEP: 150/5478 -- GLOBAL_STEP: 150
#      | > loss_disc: 2.3551981449127197  (2.47697192311287)
#      | > loss_disc_real_0: 0.1527409553527832  (0.19364245004951958)
#      | > loss_disc_real_1: 0.30903029441833496  (0.2752042641490694)
#      | > loss_disc_real_2: 0.35107266902923584  (0.27503469665845226)
#      | > loss_disc_real_3: 0.29458698630332947  (0.2735121348003545)
#      | > loss_disc_real_4: 0.3164951503276825  (0.27499594800174215)
#      | > loss_disc_real_5: 0.19136899709701538  (0.2435635480533043)
#      | > loss_0: 2.3551981449127197  (2.47697192311287)
#      | > grad_norm_0: tensor(4.6536, device='cuda:0')  (tensor(5.1061, device='cuda:0'))
#      | > loss_gen: 2.5806527137756348  (2.5187811561425533)
#      | > loss_kl: 2.4696860313415527  (22.806232016881314)
#      | > loss_feat: 3.8264636993408203  (3.8652181233962377)
#      | > loss_mel: 38.854007720947266  (57.59245391845702)
#      | > loss_duration: 2.8620433807373047  (3.407551738421122)
#      | > amp_scaler: 256.0  (488.10666666666657)
#      | > loss_1: 50.592857360839844  (90.19023666381835)
#      | > grad_norm_1: tensor(166.9684, device='cuda:0')  (tensor(200.7856, device='cuda:0'))
#      | > current_lr_0: 0.0002
#      | > current_lr_1: 0.0002
#      | > step_time: 0.149  (0.1547879044214885)
#      | > loader_time: 0.0016  (0.0021024672190348326)
#
#
#    --> TIME: 2024-09-29 06:34:37 -- STEP: 175/5478 -- GLOBAL_STEP: 175
#      | > loss_disc: 2.981318712234497  (2.4531841438157223)
#      | > loss_disc_real_0: 0.18883097171783447  (0.19037470193845893)
#      | > loss_disc_real_1: 0.2375572919845581  (0.26910207248159773)
#      | > loss_disc_real_2: 0.24592600762844086  (0.27038355444158824)
#      | > loss_disc_real_3: 0.22786901891231537  (0.26952650355441216)
#      | > loss_disc_real_4: 0.2942040264606476  (0.2708935115805693)
#      | > loss_disc_real_5: 0.18970006704330444  (0.23941906190344261)
#      | > loss_0: 2.981318712234497  (2.4531841438157223)
#      | > grad_norm_0: tensor(4.7038, device='cuda:0')  (tensor(5.3411, device='cuda:0'))
#      | > loss_gen: 1.3565958738327026  (2.5260682034492503)
#      | > loss_kl: 3.687605619430542  (20.012107466288985)
#      | > loss_feat: 2.260087013244629  (3.939045981679644)
#      | > loss_mel: 38.079750061035156  (54.89839363098144)
#      | > loss_duration: 3.319201946258545  (3.3895373739515033)
#      | > amp_scaler: 256.0  (454.94857142857137)
#      | > loss_1: 48.70323944091797  (84.76515243530271)
#      | > grad_norm_1: tensor(149.8501, device='cuda:0')  (tensor(195.1497, device='cuda:0'))
#      | > current_lr_0: 0.0002
#      | > current_lr_1: 0.0002
#      | > step_time: 0.1447  (0.15392086710248679)
#      | > loader_time: 0.001  (0.0020249829973493323)
#
#
#    --> TIME: 2024-09-29 06:34:41 -- STEP: 200/5478 -- GLOBAL_STEP: 200
#      | > loss_disc: 2.721928834915161  (2.4343981352448476)
#      | > loss_disc_real_0: 0.2735670506954193  (0.18503400122746833)
#      | > loss_disc_real_1: 0.370827853679657  (0.2655904711224136)
#      | > loss_disc_real_2: 0.42004331946372986  (0.26652541749179354)
#      | > loss_disc_real_3: 0.3067097067832947  (0.2659363647550344)
#      | > loss_disc_real_4: 0.4228847026824951  (0.267011684384197)
#      | > loss_disc_real_5: 0.28558892011642456  (0.23641718203201886)
#      | > loss_0: 2.721928834915161  (2.4343981352448476)
#      | > grad_norm_0: tensor(7.5826, device='cuda:0')  (tensor(5.4046, device='cuda:0'))
#      | > loss_gen: 2.9738423824310303  (2.5511909535527235)
#      | > loss_kl: 2.6948747634887695  (17.897338116765038)
#      | > loss_feat: 4.906438827514648  (4.021767522096635)
#      | > loss_mel: 41.44438552856445  (53.19137138366698)
#      | > loss_duration: 2.651962995529175  (3.3701422917842865)
#      | > amp_scaler: 256.0  (430.0799999999999)
#      | > loss_1: 54.671504974365234  (81.0318099975586)
#      | > grad_norm_1: tensor(165.1272, device='cuda:0')  (tensor(191.2355, device='cuda:0'))
#      | > current_lr_0: 0.0002
#      | > current_lr_1: 0.0002
#      | > step_time: 0.1468  (0.15304463624954223)
#      | > loader_time: 0.0017  (0.001964581012725832)
#
# テキスト===      筆套
# セパレーター===
# テキスト===      金仔店
# セパレーター===
# テキスト===      焦焦
# セパレーター===
# テキスト===      失業
# セパレーター===

# %%
#tts test

#English
in_pathModel = '/home/shogo/デスクトップ/Coqui-tts-20240914/TTS/TTS/run-September-14-2024_11+38AM-dbf1a08a/best_model_400488.pth'
in_config = '/home/shogo/デスクトップ/Coqui-tts-20240914/TTS/TTS/run-September-14-2024_11+38AM-dbf1a08a/config.json'
out_path = '/home/shogo/デスクトップ/Coqui-tts-20240914/TTS/TTS/run-September-14-2024_11+38AM-dbf1a08a/speech.wav'

#taiwanese
#in_pathModel = '/home/shogo/デスクトップ/Coqui-tts-20240914/TTS/TTS/run-September-16-2024_07+20PM-9b742478/best_model.pth'
#in_config = '/home/shogo/デスクトップ/Coqui-tts-20240914/TTS/TTS/run-September-16-2024_07+20PM-9b742478/config.json'
#out_path = '/home/shogo/デスクトップ/Coqui-tts-20240914/TTS/TTS/run-September-16-2024_07+20PM-9b742478/speech.wav'

#taiwanese2
#in_pathModel = '/home/shogo/デスクトップ/Coqui-tts-20240914/TTS/TTS/run-September-19-2024_01+00AM-9b742478/best_mohdel_22470.pt'
#in_config = '/home/shogo/デスクトップ/Coqui-tts-20240914/TTS/TTS/run-September-19-2024_01+00AM-9b742478/config.json'
#out_path = '/home/shogo/デスクトップ/Coqui-tts-20240914/TTS/TTS/run-September-19-2024_01+00AM-9b742478/speech.wav'

#NOW
#in_pathModel = '/home/shogo/デスクトップ/Coqui-tts-20240914/TTS/TTS/TEST/best_model.pth'
#in_config = '/home/shogo/デスクトップ/Coqui-tts-20240914/TTS/TTS/TEST/config.json'
#out_path = '/home/shogo/デスクトップ/Coqui-tts-20240914/TTS/TTS/TEST/speech.wav'



# !tts --text "Text for TTS" --model_path {in_pathModel} --config_path {in_config} --out_path {out_path}
#!tts --text "阿英" --model_path {in_pathModel} --config_path {in_config} --out_path {out_path}

#!tts --text "阿英，好來食晝矣。" --model_path {in_pathModel} --config_path {in_config} --out_path {out_path}
#!tts --text "食晝。" --model_path {in_pathModel} --config_path {in_config} --out_path {out_path}
#!tts --text "食晝才來共伊看。" --model_path {in_pathModel} --config_path {in_config} --out_path {out_path}
