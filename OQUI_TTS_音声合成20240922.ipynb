# %%
import os


# 作業ディレクトリを設定
in_path = '/home/shogo/デスクトップ/Coqui-tts-20240922/'
os.chdir(in_path)

# 作業ディレクトリをTTSに変更
os.chdir(os.path.join(in_path, "coqui-ai-TTS/TTS"))
# %env CUDA_VISIBLE_DEVICES=0
# !python train.py
# Out:
# env: CUDA_VISIBLE_DEVICES=0
# ここにきた2 nan_tw_phonemizer
# ここにきた1 NAN_TW_Phonemizer initialized
# ここにきた2 nan_tw_phonemizer
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_characters', 'add_blank', 'blank_id', 'characters', 'decode', 'encode', 'ids_to_text', 'init_from_config', 'intersperse_blank_char', 'not_found_characters', 'pad_id', 'pad_with_bos_eos', 'phonemizer', 'print_logs', 'text_cleaner', 'text_to_ids', 'use_eos_bos', 'use_phonemes']
# File not found, skipping: /home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/wavs/9c16b952-19db-4d60-a646-93729dcc3ad2.wav
# File not found, skipping: /home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/wavs/ee63bc1d-3657-46d6-b7c5-edfbdf4084a1.wav
# ef3f7966-7b7a-47e9-a11c-bfa88f531ce7|伊講你是一蕊花，這是一个比喻。|伊講你是一蕊花 這是一个比喻
#
# b828bd6e-101c-4d8b-8358-2f0eebe7a31e|山頂一蕊花，毋值平洋一枝草。|山頂一蕊花 毋值平洋一枝草
#
# bcc8282c-bedc-4707-8713-aec5c467a79e|這塊枋仔欲雕一蕊花。|這塊枋仔欲雕一蕊花
#
# 90e2c93f-71c0-4f98-b14a-30e1a23d3472|一蕊花|一蕊花
#
# 50d95462-9aff-4522-8170-1e506c72f1ac|紅嬰仔哭甲一身軀汗。|紅嬰仔哭甲一身軀汗
#
# a3799a4c-18ac-46df-b784-b0503447f830|阿明共退休金攏提去炒股票，想欲一睏仔就好額，到尾煞倒了錢，莫怪俗語講：「欲好額等後世，欲做官學做戲」。|阿明共退休金攏提去炒股票 想欲一睏仔就好額 到尾煞倒了錢 莫怪俗語講 欲好額等後世 欲做官學做戲
#
# 164beb41-9b7e-4718-ba54-1fe67c120ad7|伊跤手真緊，穡頭一睏仔就做了矣。|伊跤手真緊 穡頭一睏仔就做了矣
#
# a115db03-ca1f-42ca-8017-f9f787c5d476|伊做代誌真猛掠，一睏仔就做好矣。|伊做代誌真猛掠 一睏仔就做好矣
#
# 5c40f24f-f741-4b2b-a5c5-a66a825fb8be|遮的物件伊做一睏仔共伊食了。|遮的物件伊做一睏仔共伊食了
#
# adbd90cf-2e9e-47c2-8c8f-400090397a53|一睏仔|一睏仔
#
# Train Samples: [{'text': '落伍\n', 'audio_file': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/wavs/5ab5804c-b3af-44ba-b60c-95c58c89e36c.wav', 'speaker_name': 'ljspeech', 'root_path': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/', 'language': '', 'audio_unique_name': '#wavs/5ab5804c-b3af-44ba-b60c-95c58c89e36c', 'audio': array([0., 0., 0., ..., 0., 0., 0.])}, {'text': '男子漢\n', 'audio_file': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/wavs/ee2eb8ee-1131-44cc-ac38-9aef82be9564.wav', 'speaker_name': 'ljspeech', 'root_path': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/', 'language': '', 'audio_unique_name': '#wavs/ee2eb8ee-1131-44cc-ac38-9aef82be9564', 'audio': array([0., 0., 0., ..., 0., 0., 0.])}, {'text': '鬥榫\n', 'audio_file': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/wavs/db4bd246-00f2-4b58-9778-2db54adef129.wav', 'speaker_name': 'ljspeech', 'root_path': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/', 'language': '', 'audio_unique_name': '#wavs/db4bd246-00f2-4b58-9778-2db54adef129', 'audio': array([0., 0., 0., ..., 0., 0., 0.])}, {'text': '日鬚\n', 'audio_file': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/wavs/63e1fb8b-4e84-41d4-8022-0556aaee929f.wav', 'speaker_name': 'ljspeech', 'root_path': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/', 'language': '', 'audio_unique_name': '#wavs/63e1fb8b-4e84-41d4-8022-0556aaee929f', 'audio': array([0., 0., 0., ..., 0., 0., 0.])}, {'text': '伊的志願是欲做醫生\n', 'audio_file': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/wavs/cbcb3f8e-1e25-4cad-b7df-b17bde6641e8.wav', 'speaker_name': 'ljspeech', 'root_path': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/', 'language': '', 'audio_unique_name': '#wavs/cbcb3f8e-1e25-4cad-b7df-b17bde6641e8', 'audio': array([0., 0., 0., ..., 0., 0., 0.])}]
# Eval Samples: [{'text': '塌落來\n', 'audio_file': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/wavs/09d92121-8d06-4649-9e41-4e5abeedfef4.wav', 'speaker_name': 'ljspeech', 'root_path': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/', 'language': '', 'audio_unique_name': '#wavs/09d92121-8d06-4649-9e41-4e5abeedfef4', 'audio': array([0., 0., 0., ..., 0., 0., 0.])}, {'text': '伊欲出門去做工 煞臨時接著電話 行袂開跤\n', 'audio_file': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/wavs/fa45e2a1-4965-4b75-87c8-99591fb646d5.wav', 'speaker_name': 'ljspeech', 'root_path': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/', 'language': '', 'audio_unique_name': '#wavs/fa45e2a1-4965-4b75-87c8-99591fb646d5', 'audio': array([0., 0., 0., ..., 0., 0., 0.])}, {'text': '光明的前途\n', 'audio_file': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/wavs/d4589d20-8b6d-4fb8-a49e-5d58383ae31b.wav', 'speaker_name': 'ljspeech', 'root_path': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/', 'language': '', 'audio_unique_name': '#wavs/d4589d20-8b6d-4fb8-a49e-5d58383ae31b', 'audio': array([0., 0., 0., ..., 0., 0., 0.])}, {'text': '青苔仔是一種細隻鳥仔 佇都市的公園抑是學校攏看會著伊的影跡\n', 'audio_file': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/wavs/ac7dda2d-7490-4e01-9395-bc4ed74593d7.wav', 'speaker_name': 'ljspeech', 'root_path': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/', 'language': '', 'audio_unique_name': '#wavs/ac7dda2d-7490-4e01-9395-bc4ed74593d7', 'audio': array([-0.00137329, -0.0015564 , -0.00161743, ..., -0.00708008,
#        -0.00714111, -0.00738525])}, {'text': '紮禮物送伊\n', 'audio_file': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/wavs/6937d6b4-621d-4538-9e0c-38412a8d9ac3.wav', 'speaker_name': 'ljspeech', 'root_path': '/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/../recipes/ljspeech/LJSpeech-1.1/', 'language': '', 'audio_unique_name': '#wavs/6937d6b4-621d-4538-9e0c-38412a8d9ac3', 'audio': array([-2.13623047e-04, -1.83105469e-04, -1.22070312e-04, ...,
#        -3.05175781e-05, -9.15527344e-05, -9.15527344e-05])}]
# トレーニングサンプル数: 21911
# 評価サンプル数: 3867
#  > Training Environment:
#  | > Backend: Torch
#  | > Mixed precision: True
#  | > Precision: fp16
#  | > Current device: 0
#  | > Num. of GPUs: 1
#  | > Num. of CPUs: 24
#  | > Num. of Torch Threads: 16
#  | > Torch seed: 54321
#  | > Torch CUDNN: True
#  | > Torch CUDNN deterministic: False
#  | > Torch CUDNN benchmark: False
#  | > Torch TF32 MatMul: False
#  > Start Tensorboard: tensorboard --logdir=/home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/vits_ljspeech-September-28-2024_11+52AM-d9bd1f0
# /home/shogo/.local/lib/python3.11/site-packages/trainer/trainer.py:331: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler()
#
#  > Model has 83875180 parameters
#
#  > EPOCH: 0/1000
#  --> /home/shogo/デスクトップ/Coqui-tts-20240922/coqui-ai-TTS/TTS/vits_ljspeech-September-28-2024_11+52AM-d9bd1f0
#   0%|                                                 | 0/21911 [00:00<?, ?it/s]テキスト===      落伍
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 落伍
# API response text1: "lok4 ngoo2"
# API response text2: lok4 ngoo2
# pinyins_flat_list-  ['lok4', ' ', 'ngoo2']
# pinyined_text3- ['lok4', ' ', 'ngoo2']
# token - lok4
# pinyin- lok
# shisei- 4
# onso- lɔk
# onso to shisei - lɔk4
# token -
# token - ngoo2
# pinyin- ngoo
# shisei- 2
# onso- ŋo
# onso to shisei - ŋo2
# results- lɔk4 ŋo2
# 結果 =  lɔk4 ŋo2
#   0%|                                       | 1/21911 [00:00<2:03:55,  2.95it/s]テキスト===      男子漢
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 男子漢
# API response text1: "lam5 tsu2 han3"
# API response text2: lam5 tsu2 han3
# pinyins_flat_list-  ['lam5', ' ', 'tsu2', ' ', 'han3']
# pinyined_text3- ['lam5', ' ', 'tsu2', ' ', 'han3']
# token - lam5
# pinyin- lam
# shisei- 5
# onso- lam
# onso to shisei - lam5
# token -
# token - tsu2
# pinyin- tsu
# shisei- 2
# onso- tsu
# onso to shisei - tsu2
# token -
# token - han3
# pinyin- han
# shisei- 3
# onso-
# onso to shisei - 3
# results- lam5 tsu2 3
# 結果 =  lam5 tsu2 3
#   0%|                                       | 2/21911 [00:00<2:19:23,  2.62it/s]テキスト===      鬥榫
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 鬥榫
# API response text1: "tau3 sun2"
# API response text2: tau3 sun2
# pinyins_flat_list-  ['tau3', ' ', 'sun2']
# pinyined_text3- ['tau3', ' ', 'sun2']
# token - tau3
# pinyin- tau
# shisei- 3
# onso- tau
# onso to shisei - tau3
# token -
# token - sun2
# pinyin- sun
# shisei- 2
# onso-
# onso to shisei - 2
# results- tau3 2
# 結果 =  tau3 2
#   0%|                                       | 3/21911 [00:01<1:57:54,  3.10it/s]テキスト===      日鬚
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 日鬚
# API response text1: "jit tshiu1"
# API response text2: jit tshiu1
# pinyins_flat_list-  ['jit', ' ', 'tshiu1']
# pinyined_text3- ['jit', ' ', 'tshiu1']
# token - jit
# token -
# token - tshiu1
# pinyin- tshiu
# shisei- 1
# onso- tɕʰiu
# onso to shisei - tɕʰiu1
# results- jit tɕʰiu1
# 結果 =  jit tɕʰiu1
#   0%|                                       | 4/21911 [00:01<1:52:03,  3.26it/s]テキスト===      伊的志願是欲做醫生
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 伊的志願是欲做醫生
# API response text1: "i1 tik4 tsi3 guan7 si7 beh4 tso i1 sing1"
# API response text2: i1 tik4 tsi3 guan7 si7 beh4 tso i1 sing1
# pinyins_flat_list-  ['i1', ' ', 'tik4', ' ', 'tsi3', ' ', 'guan7', ' ', 'si7', ' ', 'beh4', ' ', 'tso', ' ', 'i1', ' ', 'sing1']
# pinyined_text3- ['i1', ' ', 'tik4', ' ', 'tsi3', ' ', 'guan7', ' ', 'si7', ' ', 'beh4', ' ', 'tso', ' ', 'i1', ' ', 'sing1']
# token - i1
# pinyin- i
# shisei- 1
# onso- i
# onso to shisei - i1
# token -
# token - tik4
# pinyin- tik
# shisei- 4
# onso- tɪk
# onso to shisei - tɪk4
# token -
# token - tsi3
# pinyin- tsi
# shisei- 3
# onso- t͡ɕ
# onso to shisei - t͡ɕ3
# token -
# token - guan7
# pinyin- guan
# shisei- 7
# onso- guan
# onso to shisei - guan7
# token -
# token - si7
# pinyin- si
# shisei- 7
# onso- ɕ
# onso to shisei - ɕ7
# token -
# token - beh4
# pinyin- beh
# shisei- 4
# onso-
# onso to shisei - 4
# token -
# token - tso
# token -
# token - i1
# pinyin- i
# shisei- 1
# onso- i
# onso to shisei - i1
# token -
# token - sing1
# pinyin- sing
# shisei- 1
# onso- siŋ
# onso to shisei - siŋ1
# results- i1 tɪk4 t͡ɕ3 guan7 ɕ7 4 tso i1 siŋ1
# 結果 =  i1 tɪk4 t͡ɕ3 guan7 ɕ7 4 tso i1 siŋ1
#   0%|                                       | 5/21911 [00:01<2:31:43,  2.41it/s]テキスト===      雪文沫
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 雪文沫
# API response text1: "sap4 bun5 phueh"
# API response text2: sap4 bun5 phueh
# pinyins_flat_list-  ['sap4', ' ', 'bun5', ' ', 'phueh']
# pinyined_text3- ['sap4', ' ', 'bun5', ' ', 'phueh']
# token - sap4
# pinyin- sap
# shisei- 4
# onso- sap
# onso to shisei - sap4
# token -
# token - bun5
# pinyin- bun
# shisei- 5
# onso-
# onso to shisei - 5
# token -
# token - phueh
# results- sap4 5 phueh
# 結果 =  sap4 5 phueh
#   0%|                                       | 6/21911 [00:02<2:25:00,  2.52it/s]テキスト===      你莫叫是講你做的遐的失德代無人知 俗語講 攑頭三尺有神明 你緊縒慢會得著報應
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 你莫叫是講你做的遐的失德代無人知 俗語講 攑頭三尺有神明 你緊縒慢會得著報應
# API response text1: "li2 mai3 kio3 si7 kong2 li2 tso tik4 hia1  e5 sit4 tik4 te7 bo5 lang5 tsai1  siok4 gi kong2  giah4 thau5 sann1 tshioh4 u7 sin5 mia5  li2 kin2 tsuah4 ban7 e7 tit4 tu3 po3 ing3"
# API response text2: li2 mai3 kio3 si7 kong2 li2 tso tik4 hia1  e5 sit4 tik4 te7 bo5 lang5 tsai1  siok4 gi kong2  giah4 thau5 sann1 tshioh4 u7 sin5 mia5  li2 kin2 tsuah4 ban7 e7 tit4 tu3 po3 ing3
# pinyins_flat_list-  ['li2', ' ', 'mai3', ' ', 'kio3', ' ', 'si7', ' ', 'kong2', ' ', 'li2', ' ', 'tso', ' ', 'tik4', ' ', 'hia1', ' ', 'e5', ' ', 'sit4', ' ', 'tik4', ' ', 'te7', ' ', 'bo5', ' ', 'lang5', ' ', 'tsai1', ' ', 'siok4', ' ', 'gi', ' ', 'kong2', ' ', 'giah4', ' ', 'thau5', ' ', 'sann1', ' ', 'tshioh4', ' ', 'u7', ' ', 'sin5', ' ', 'mia5', ' ', 'li2', ' ', 'kin2', ' ', 'tsuah4', ' ', 'ban7', ' ', 'e7', ' ', 'tit4', ' ', 'tu3', ' ', 'po3', ' ', 'ing3']
# pinyined_text3- ['li2', ' ', 'mai3', ' ', 'kio3', ' ', 'si7', ' ', 'kong2', ' ', 'li2', ' ', 'tso', ' ', 'tik4', ' ', 'hia1', ' ', 'e5', ' ', 'sit4', ' ', 'tik4', ' ', 'te7', ' ', 'bo5', ' ', 'lang5', ' ', 'tsai1', ' ', 'siok4', ' ', 'gi', ' ', 'kong2', ' ', 'giah4', ' ', 'thau5', ' ', 'sann1', ' ', 'tshioh4', ' ', 'u7', ' ', 'sin5', ' ', 'mia5', ' ', 'li2', ' ', 'kin2', ' ', 'tsuah4', ' ', 'ban7', ' ', 'e7', ' ', 'tit4', ' ', 'tu3', ' ', 'po3', ' ', 'ing3']
# token - li2
# pinyin- li
# shisei- 2
# onso- li
# onso to shisei - li2
# token -
# token - mai3
# pinyin- mai
# shisei- 3
# onso- mai
# onso to shisei - mai3
# token -
# token - kio3
# pinyin- kio
# shisei- 3
# onso- kiu
# onso to shisei - kiu3
# token -
# token - si7
# pinyin- si
# shisei- 7
# onso- ɕ
# onso to shisei - ɕ7
# token -
# token - kong2
# pinyin- kong
# shisei- 2
# onso- kɔŋ
# onso to shisei - kɔŋ2
# token -
# token - li2
# pinyin- li
# shisei- 2
# onso- li
# onso to shisei - li2
# token -
# token - tso
# token -
# token - tik4
# pinyin- tik
# shisei- 4
# onso- tɪk
# onso to shisei - tɪk4
# token -
# token - hia1
# pinyin- hia
# shisei- 1
# onso-
# onso to shisei - 1
# token -
# token - e5
# pinyin- e
# shisei- 5
# onso- e
# onso to shisei - e5
# token -
# token - sit4
# pinyin- sit
# shisei- 4
# onso- sit
# onso to shisei - sit4
# token -
# token - tik4
# pinyin- tik
# shisei- 4
# onso- tɪk
# onso to shisei - tɪk4
# token -
# token - te7
# pinyin- te
# shisei- 7
# onso- te
# onso to shisei - te7
# token -
# token - bo5
# pinyin- bo
# shisei- 5
# onso- bo
# onso to shisei - bo5
# token -
# token - lang5
# pinyin- lang
# shisei- 5
# onso-
# onso to shisei - 5
# token -
# token - tsai1
# pinyin- tsai
# shisei- 1
# onso- tsai
# onso to shisei - tsai1
# token -
# token - siok4
# pinyin- siok
# shisei- 4
# onso- sɪɔk
# onso to shisei - sɪɔk4
# token -
# token - gi
# token -
# token - kong2
# pinyin- kong
# shisei- 2
# onso- kɔŋ
# onso to shisei - kɔŋ2
# token -
# token - giah4
# pinyin- giah
# shisei- 4
# onso-
# onso to shisei - 4
# token -
# token - thau5
# pinyin- thau
# shisei- 5
# onso- tʰau
# onso to shisei - tʰau5
# token -
# token - sann1
# pinyin- sann
# shisei- 1
# onso- sã
# onso to shisei - sã1
# token -
# token - tshioh4
# pinyin- tshioh
# shisei- 4
# onso- tɕʰɪəʔ
# onso to shisei - tɕʰɪəʔ4
# token -
# token - u7
# pinyin- u
# shisei- 7
# onso- u
# onso to shisei - u7
# token -
# token - sin5
# pinyin- sin
# shisei- 5
# onso- ɕin
# onso to shisei - ɕin5
# token -
# token - mia5
# pinyin- mia
# shisei- 5
# onso-
# onso to shisei - 5
# token -
# token - li2
# pinyin- li
# shisei- 2
# onso- li
# onso to shisei - li2
# token -
# token - kin2
# pinyin- kin
# shisei- 2
# onso- kin
# onso to shisei - kin2
# token -
# token - tsuah4
# pinyin- tsuah
# shisei- 4
# onso-
# onso to shisei - 4
# token -
# token - ban7
# pinyin- ban
# shisei- 7
# onso-
# onso to shisei - 7
# token -
# token - e7
# pinyin- e
# shisei- 7
# onso- e
# onso to shisei - e7
# token -
# token - tit4
# pinyin- tit
# shisei- 4
# onso- tit
# onso to shisei - tit4
# token -
# token - tu3
# pinyin- tu
# shisei- 3
# onso- tu
# onso to shisei - tu3
# token -
# token - po3
# pinyin- po
# shisei- 3
# onso- po
# onso to shisei - po3
# token -
# token - ing3
# pinyin- ing
# shisei- 3
# onso- iŋ
# onso to shisei - iŋ3
# results- li2 mai3 kiu3 ɕ7 kɔŋ2 li2 tso tɪk4 1 e5 sit4 tɪk4 te7 bo5 5 tsai1 sɪɔk4 gi kɔŋ2 4 tʰau5 sã1 tɕʰɪəʔ4 u7 ɕin5 5 li2 kin2 4 7 e7 tit4 tu3 po3 iŋ3
# 結果 =  li2 mai3 kiu3 ɕ7 kɔŋ2 li2 tso tɪk4 1 e5 sit4 tɪk4 te7 bo5 5 tsai1 sɪɔk4 gi kɔŋ2 4 tʰau5 sã1 tɕʰɪəʔ4 u7 ɕin5 5 li2 kin2 4 7 e7 tit4 tu3 po3 iŋ3
#   0%|                                       | 7/21911 [00:03<4:47:25,  1.27it/s]テキスト===      有的物件好趁 有的末趁 掠長補短生理猶會做得
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 有的物件好趁 有的末趁 掠長補短生理猶會做得
# API response text1: "u7 tik4 mih4 kiann honn3 than3  u7 tik4 buat than3  liah4 tng1 poo2 te2 sing1 li2 iu1 e7 tso3 tit"
# API response text2: u7 tik4 mih4 kiann honn3 than3  u7 tik4 buat than3  liah4 tng1 poo2 te2 sing1 li2 iu1 e7 tso3 tit
# pinyins_flat_list-  ['u7', ' ', 'tik4', ' ', 'mih4', ' ', 'kiann', ' ', 'honn3', ' ', 'than3', ' ', 'u7', ' ', 'tik4', ' ', 'buat', ' ', 'than3', ' ', 'liah4', ' ', 'tng1', ' ', 'poo2', ' ', 'te2', ' ', 'sing1', ' ', 'li2', ' ', 'iu1', ' ', 'e7', ' ', 'tso3', ' ', 'tit']
# pinyined_text3- ['u7', ' ', 'tik4', ' ', 'mih4', ' ', 'kiann', ' ', 'honn3', ' ', 'than3', ' ', 'u7', ' ', 'tik4', ' ', 'buat', ' ', 'than3', ' ', 'liah4', ' ', 'tng1', ' ', 'poo2', ' ', 'te2', ' ', 'sing1', ' ', 'li2', ' ', 'iu1', ' ', 'e7', ' ', 'tso3', ' ', 'tit']
# token - u7
# pinyin- u
# shisei- 7
# onso- u
# onso to shisei - u7
# token -
# token - tik4
# pinyin- tik
# shisei- 4
# onso- tɪk
# onso to shisei - tɪk4
# token -
# token - mih4
# pinyin- mih
# shisei- 4
# onso-
# onso to shisei - 4
# token -
# token - kiann
# token -
# token - honn3
# pinyin- honn
# shisei- 3
# onso- hɔ̃
# onso to shisei - hɔ̃3
# token -
# token - than3
# pinyin- than
# shisei- 3
# onso-
# onso to shisei - 3
# token -
# token - u7
# pinyin- u
# shisei- 7
# onso- u
# onso to shisei - u7
# token -
# token - tik4
# pinyin- tik
# shisei- 4
# onso- tɪk
# onso to shisei - tɪk4
# token -
# token - buat
# token -
# token - than3
# pinyin- than
# shisei- 3
# onso-
# onso to shisei - 3
# token -
# token - liah4
# pinyin- liah
# shisei- 4
# onso-
# onso to shisei - 4
# token -
# token - tng1
# pinyin- tng
# shisei- 1
# onso- tŋ̍
# onso to shisei - tŋ̍1
# token -
# token - poo2
# pinyin- poo
# shisei- 2
# onso- pɔ
# onso to shisei - pɔ2
# token -
# token - te2
# pinyin- te
# shisei- 2
# onso- te
# onso to shisei - te2
# token -
# token - sing1
# pinyin- sing
# shisei- 1
# onso- siŋ
# onso to shisei - siŋ1
# token -
# token - li2
# pinyin- li
# shisei- 2
# onso- li
# onso to shisei - li2
# token -
# token - iu1
# pinyin- iu
# shisei- 1
# onso- iu
# onso to shisei - iu1
# token -
# token - e7
# pinyin- e
# shisei- 7
# onso- e
# onso to shisei - e7
# token -
# token - tso3
# pinyin- tso
# shisei- 3
# onso- tso
# onso to shisei - tso3
# token -
# token - tit
# results- u7 tɪk4 4 kiann hɔ̃3 3 u7 tɪk4 buat 3 4 tŋ̍1 pɔ2 te2 siŋ1 li2 iu1 e7 tso3 tit
# 結果 =  u7 tɪk4 4 kiann hɔ̃3 3 u7 tɪk4 buat 3 4 tŋ̍1 pɔ2 te2 siŋ1 li2 iu1 e7 tso3 tit
#   0%|                                       | 8/21911 [00:04<4:58:02,  1.22it/s]テキスト===      人講 好也一句 歹也一句 佮人接接咱就講寡好聽話 莫歹喙罵人 較袂得失人
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 人講 好也一句 歹也一句 佮人接接咱就講寡好聽話 莫歹喙罵人 較袂得失人
# API response text1: "lang5 kong2  honn3 ia7 tsit4 ku3  tai2 ia7 tsit4 ku3  kap4 lang5 tsih4 tsiap4 lan2 tsiu7 kong2 kua2 ho2 thiann1 ue7  mai3 phainn2 tshui3 me lang5  khah4 be7 tit sit4 lang5"
# API response text2: lang5 kong2  honn3 ia7 tsit4 ku3  tai2 ia7 tsit4 ku3  kap4 lang5 tsih4 tsiap4 lan2 tsiu7 kong2 kua2 ho2 thiann1 ue7  mai3 phainn2 tshui3 me lang5  khah4 be7 tit sit4 lang5
# pinyins_flat_list-  ['lang5', ' ', 'kong2', ' ', 'honn3', ' ', 'ia7', ' ', 'tsit4', ' ', 'ku3', ' ', 'tai2', ' ', 'ia7', ' ', 'tsit4', ' ', 'ku3', ' ', 'kap4', ' ', 'lang5', ' ', 'tsih4', ' ', 'tsiap4', ' ', 'lan2', ' ', 'tsiu7', ' ', 'kong2', ' ', 'kua2', ' ', 'ho2', ' ', 'thiann1', ' ', 'ue7', ' ', 'mai3', ' ', 'phainn2', ' ', 'tshui3', ' ', 'me', ' ', 'lang5', ' ', 'khah4', ' ', 'be7', ' ', 'tit', ' ', 'sit4', ' ', 'lang5', ' ']
# pinyined_text3- ['lang5', ' ', 'kong2', ' ', 'honn3', ' ', 'ia7', ' ', 'tsit4', ' ', 'ku3', ' ', 'tai2', ' ', 'ia7', ' ', 'tsit4', ' ', 'ku3', ' ', 'kap4', ' ', 'lang5', ' ', 'tsih4', ' ', 'tsiap4', ' ', 'lan2', ' ', 'tsiu7', ' ', 'kong2', ' ', 'kua2', ' ', 'ho2', ' ', 'thiann1', ' ', 'ue7', ' ', 'mai3', ' ', 'phainn2', ' ', 'tshui3', ' ', 'me', ' ', 'lang5', ' ', 'khah4', ' ', 'be7', ' ', 'tit', ' ', 'sit4', ' ', 'lang5', ' ']
# token - lang5
# pinyin- lang
# shisei- 5
# onso-
# onso to shisei - 5
# token -
# token - kong2
# pinyin- kong
# shisei- 2
# onso- kɔŋ
# onso to shisei - kɔŋ2
# token -
# token - honn3
# pinyin- honn
# shisei- 3
# onso- hɔ̃
# onso to shisei - hɔ̃3
# token -
# token - ia7
# pinyin- ia
# shisei- 7
# onso- ia
# onso to shisei - ia7
# token -
# token - tsit4
# pinyin- tsit
# shisei- 4
# onso- tɕit
# onso to shisei - tɕit4
# token -
# token - ku3
# pinyin- ku
# shisei- 3
# onso- ku
# onso to shisei - ku3
# token -
# token - tai2
# pinyin- tai
# shisei- 2
# onso- tai
# onso to shisei - tai2
# token -
# token - ia7
# pinyin- ia
# shisei- 7
# onso- ia
# onso to shisei - ia7
# token -
# token - tsit4
# pinyin- tsit
# shisei- 4
# onso- tɕit
# onso to shisei - tɕit4
# token -
# token - ku3
# pinyin- ku
# shisei- 3
# onso- ku
# onso to shisei - ku3
# token -
# token - kap4
# pinyin- kap
# shisei- 4
# onso- kap
# onso to shisei - kap4
# token -
# token - lang5
# pinyin- lang
# shisei- 5
# onso-
# onso to shisei - 5
# token -
# token - tsih4
# pinyin- tsih
# shisei- 4
# onso-
# onso to shisei - 4
# token -
# token - tsiap4
# pinyin- tsiap
# shisei- 4
# onso- tɕiap
# onso to shisei - tɕiap4
# token -
# token - lan2
# pinyin- lan
# shisei- 2
# onso-
# onso to shisei - 2
# token -
# token - tsiu7
# pinyin- tsiu
# shisei- 7
# onso- tsiu
# onso to shisei - tsiu7
# token -
# token - kong2
# pinyin- kong
# shisei- 2
# onso- kɔŋ
# onso to shisei - kɔŋ2
# token -
# token - kua2
# pinyin- kua
# shisei- 2
# onso- kua
# onso to shisei - kua2
# token -
# token - ho2
# pinyin- ho
# shisei- 2
# onso- ho
# onso to shisei - ho2
# token -
# token - thiann1
# pinyin- thiann
# shisei- 1
# onso-
# onso to shisei - 1
# token -
# token - ue7
# pinyin- ue
# shisei- 7
# onso- ue
# onso to shisei - ue7
# token -
# token - mai3
# pinyin- mai
# shisei- 3
# onso- mai
# onso to shisei - mai3
# token -
# token - phainn2
# pinyin- phainn
# shisei- 2
# onso- pʰaĩ
# onso to shisei - pʰaĩ2
# token -
# token - tshui3
# pinyin- tshui
# shisei- 3
# onso-
# onso to shisei - 3
# token -
# token - me
# token -
# token - lang5
# pinyin- lang
# shisei- 5
# onso-
# onso to shisei - 5
# token -
# token - khah4
# pinyin- khah
# shisei- 4
# onso- kʰaʔ
# onso to shisei - kʰaʔ4
# token -
# token - be7
# pinyin- be
# shisei- 7
# onso- be
# onso to shisei - be7
# token -
# token - tit
# token -
# token - sit4
# pinyin- sit
# shisei- 4
# onso- sit
# onso to shisei - sit4
# token -
# token - lang5
# pinyin- lang
# shisei- 5
# onso-
# onso to shisei - 5
# token -
# results- 5 kɔŋ2 hɔ̃3 ia7 tɕit4 ku3 tai2 ia7 tɕit4 ku3 kap4 5 4 tɕiap4 2 tsiu7 kɔŋ2 kua2 ho2 1 ue7 mai3 pʰaĩ2 3 me 5 kʰaʔ4 be7 tit sit4 5
# 結果 =  5 kɔŋ2 hɔ̃3 ia7 tɕit4 ku3 tai2 ia7 tɕit4 ku3 kap4 5 4 tɕiap4 2 tsiu7 kɔŋ2 kua2 ho2 1 ue7 mai3 pʰaĩ2 3 me 5 kʰaʔ4 be7 tit sit4 5
#   0%|                                       | 9/21911 [00:06<7:02:08,  1.16s/it]テキスト===      替身
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 替身
# API response text1: "the3 sin"
# API response text2: the3 sin
# pinyins_flat_list-  ['the3', ' ', 'sin']
# pinyined_text3- ['the3', ' ', 'sin']
# token - the3
# pinyin- the
# shisei- 3
# onso- tʰe
# onso to shisei - tʰe3
# token -
# token - sin
# results- tʰe3 sin
# 結果 =  tʰe3 sin
#   0%|                                      | 10/21911 [00:06<5:14:36,  1.16it/s]テキスト===      恁查某囝啥物時陣欲過門
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 恁查某囝啥物時陣欲過門
# API response text1: "lin2 tsa1 boo2 kiann2 siann2 mih4 si5 tsun7 beh4 kue3 mng"
# API response text2: lin2 tsa1 boo2 kiann2 siann2 mih4 si5 tsun7 beh4 kue3 mng
# pinyins_flat_list-  ['lin2', ' ', 'tsa1', ' ', 'boo2', ' ', 'kiann2', ' ', 'siann2', ' ', 'mih4', ' ', 'si5', ' ', 'tsun7', ' ', 'beh4', ' ', 'kue3', ' ', 'mng']
# pinyined_text3- ['lin2', ' ', 'tsa1', ' ', 'boo2', ' ', 'kiann2', ' ', 'siann2', ' ', 'mih4', ' ', 'si5', ' ', 'tsun7', ' ', 'beh4', ' ', 'kue3', ' ', 'mng']
# token - lin2
# pinyin- lin
# shisei- 2
# onso- lin
# onso to shisei - lin2
# token -
# token - tsa1
# pinyin- tsa
# shisei- 1
# onso- tsa
# onso to shisei - tsa1
# token -
# token - boo2
# pinyin- boo
# shisei- 2
# onso- bɔ
# onso to shisei - bɔ2
# token -
# token - kiann2
# pinyin- kiann
# shisei- 2
# onso-
# onso to shisei - 2
# token -
# token - siann2
# pinyin- siann
# shisei- 2
# onso- ɕiã
# onso to shisei - ɕiã2
# token -
# token - mih4
# pinyin- mih
# shisei- 4
# onso-
# onso to shisei - 4
# token -
# token - si5
# pinyin- si
# shisei- 5
# onso- ɕ
# onso to shisei - ɕ5
# token -
# token - tsun7
# pinyin- tsun
# shisei- 7
# onso-
# onso to shisei - 7
# token -
# token - beh4
# pinyin- beh
# shisei- 4
# onso-
# onso to shisei - 4
# token -
# token - kue3
# pinyin- kue
# shisei- 3
# onso- kue
# onso to shisei - kue3
# token -
# token - mng
# results- lin2 tsa1 bɔ2 2 ɕiã2 4 ɕ5 7 4 kue3 mng
# 結果 =  lin2 tsa1 bɔ2 2 ɕiã2 4 ɕ5 7 4 kue3 mng
#   0%|                                      | 11/21911 [00:07<4:38:46,  1.31it/s]テキスト===      份生理
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 份生理
# API response text1: "hun7 sing1 li2"
# API response text2: hun7 sing1 li2
# pinyins_flat_list-  ['hun7', ' ', 'sing1', ' ', 'li2']
# pinyined_text3- ['hun7', ' ', 'sing1', ' ', 'li2']
# token - hun7
# pinyin- hun
# shisei- 7
# onso-
# onso to shisei - 7
# token -
# token - sing1
# pinyin- sing
# shisei- 1
# onso- siŋ
# onso to shisei - siŋ1
# token -
# token - li2
# pinyin- li
# shisei- 2
# onso- li
# onso to shisei - li2
# results- 7 siŋ1 li2
# 結果 =  7 siŋ1 li2
#   0%|                                      | 12/21911 [00:07<3:53:35,  1.56it/s]テキスト===      伊今仔日穿甲花巴哩貓
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 伊今仔日穿甲花巴哩貓
# API response text1: "i1 kin1 a2 jit tshuan1 kap4 hue1 pa1 li1 niau1"
# API response text2: i1 kin1 a2 jit tshuan1 kap4 hue1 pa1 li1 niau1
# pinyins_flat_list-  ['i1', ' ', 'kin1', ' ', 'a2', ' ', 'jit', ' ', 'tshuan1', ' ', 'kap4', ' ', 'hue1', ' ', 'pa1', ' ', 'li1', ' ', 'niau1']
# pinyined_text3- ['i1', ' ', 'kin1', ' ', 'a2', ' ', 'jit', ' ', 'tshuan1', ' ', 'kap4', ' ', 'hue1', ' ', 'pa1', ' ', 'li1', ' ', 'niau1']
# token - i1
# pinyin- i
# shisei- 1
# onso- i
# onso to shisei - i1
# token -
# token - kin1
# pinyin- kin
# shisei- 1
# onso- kin
# onso to shisei - kin1
# token -
# token - a2
# pinyin- a
# shisei- 2
# onso- a
# onso to shisei - a2
# token -
# token - jit
# token -
# token - tshuan1
# pinyin- tshuan
# shisei- 1
# onso- tsʰuan
# onso to shisei - tsʰuan1
# token -
# token - kap4
# pinyin- kap
# shisei- 4
# onso- kap
# onso to shisei - kap4
# token -
# token - hue1
# pinyin- hue
# shisei- 1
# onso- hue
# onso to shisei - hue1
# token -
# token - pa1
# pinyin- pa
# shisei- 1
# onso- pa
# onso to shisei - pa1
# token -
# token - li1
# pinyin- li
# shisei- 1
# onso- li
# onso to shisei - li1
# token -
# token - niau1
# pinyin- niau
# shisei- 1
# onso-
# onso to shisei - 1
# results- i1 kin1 a2 jit tsʰuan1 kap4 hue1 pa1 li1 1
# 結果 =  i1 kin1 a2 jit tsʰuan1 kap4 hue1 pa1 li1 1
#   0%|                                      | 13/21911 [00:08<3:57:56,  1.53it/s]テキスト===      番薑仔醬
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 番薑仔醬
# API response text1: "huan1 kiunn1 a2 tsiunn3"
# API response text2: huan1 kiunn1 a2 tsiunn3
# pinyins_flat_list-  ['huan1', ' ', 'kiunn1', ' ', 'a2', ' ', 'tsiunn3']
# pinyined_text3- ['huan1', ' ', 'kiunn1', ' ', 'a2', ' ', 'tsiunn3']
# token - huan1
# pinyin- huan
# shisei- 1
# onso- huan
# onso to shisei - huan1
# token -
# token - kiunn1
# pinyin- kiunn
# shisei- 1
# onso- kiũ
# onso to shisei - kiũ1
# token -
# token - a2
# pinyin- a
# shisei- 2
# onso- a
# onso to shisei - a2
# token -
# token - tsiunn3
# pinyin- tsiunn
# shisei- 3
# onso- tsiũ
# onso to shisei - tsiũ3
# results- huan1 kiũ1 a2 tsiũ3
# 結果 =  huan1 kiũ1 a2 tsiũ3
#   0%|                                      | 14/21911 [00:08<3:12:39,  1.89it/s]テキスト===      初九天公生 咱做伙求天公伯仔保庇咱一家口仔平安順序
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 初九天公生 咱做伙求天公伯仔保庇咱一家口仔平安順序
# API response text1: "tshoo1 kiu2 thinn1 kong1 senn  lan2 tso3 hue kiu5 thinn1 kong1 peh4  a2 po2 pi3 lan2 tsit4 ke1 khio2 tsu2 ping5 an1 sun7 si7"
# API response text2: tshoo1 kiu2 thinn1 kong1 senn  lan2 tso3 hue kiu5 thinn1 kong1 peh4  a2 po2 pi3 lan2 tsit4 ke1 khio2 tsu2 ping5 an1 sun7 si7
# pinyins_flat_list-  ['tshoo1', ' ', 'kiu2', ' ', 'thinn1', ' ', 'kong1', ' ', 'senn', ' ', 'lan2', ' ', 'tso3', ' ', 'hue', ' ', 'kiu5', ' ', 'thinn1', ' ', 'kong1', ' ', 'peh4', ' ', 'a2', ' ', 'po2', ' ', 'pi3', ' ', 'lan2', ' ', 'tsit4', ' ', 'ke1', ' ', 'khio2', ' ', 'tsu2', ' ', 'ping5', ' ', 'an1', ' ', 'sun7', ' ', 'si7']
# pinyined_text3- ['tshoo1', ' ', 'kiu2', ' ', 'thinn1', ' ', 'kong1', ' ', 'senn', ' ', 'lan2', ' ', 'tso3', ' ', 'hue', ' ', 'kiu5', ' ', 'thinn1', ' ', 'kong1', ' ', 'peh4', ' ', 'a2', ' ', 'po2', ' ', 'pi3', ' ', 'lan2', ' ', 'tsit4', ' ', 'ke1', ' ', 'khio2', ' ', 'tsu2', ' ', 'ping5', ' ', 'an1', ' ', 'sun7', ' ', 'si7']
# token - tshoo1
# pinyin- tshoo
# shisei- 1
# onso- tsʰɔ
# onso to shisei - tsʰɔ1
# token -
# token - kiu2
# pinyin- kiu
# shisei- 2
# onso- kiu
# onso to shisei - kiu2
# token -
# token - thinn1
# pinyin- thinn
# shisei- 1
# onso- tʰĩ
# onso to shisei - tʰĩ1
# token -
# token - kong1
# pinyin- kong
# shisei- 1
# onso- kɔŋ
# onso to shisei - kɔŋ1
# token -
# token - senn
# token -
# token - lan2
# pinyin- lan
# shisei- 2
# onso-
# onso to shisei - 2
# token -
# token - tso3
# pinyin- tso
# shisei- 3
# onso- tso
# onso to shisei - tso3
# token -
# token - hue
# token -
# token - kiu5
# pinyin- kiu
# shisei- 5
# onso- kiu
# onso to shisei - kiu5
# token -
# token - thinn1
# pinyin- thinn
# shisei- 1
# onso- tʰĩ
# onso to shisei - tʰĩ1
# token -
# token - kong1
# pinyin- kong
# shisei- 1
# onso- kɔŋ
# onso to shisei - kɔŋ1
# token -
# token - peh4
# pinyin- peh
# shisei- 4
# onso-
# onso to shisei - 4
# token -
# token - a2
# pinyin- a
# shisei- 2
# onso- a
# onso to shisei - a2
# token -
# token - po2
# pinyin- po
# shisei- 2
# onso- po
# onso to shisei - po2
# token -
# token - pi3
# pinyin- pi
# shisei- 3
# onso- pi
# onso to shisei - pi3
# token -
# token - lan2
# pinyin- lan
# shisei- 2
# onso-
# onso to shisei - 2
# token -
# token - tsit4
# pinyin- tsit
# shisei- 4
# onso- tɕit
# onso to shisei - tɕit4
# token -
# token - ke1
# pinyin- ke
# shisei- 1
# onso- ke
# onso to shisei - ke1
# token -
# token - khio2
# pinyin- khio
# shisei- 2
# onso- kʰiu
# onso to shisei - kʰiu2
# token -
# token - tsu2
# pinyin- tsu
# shisei- 2
# onso- tsu
# onso to shisei - tsu2
# token -
# token - ping5
# pinyin- ping
# shisei- 5
# onso- piŋ
# onso to shisei - piŋ5
# token -
# token - an1
# pinyin- an
# shisei- 1
# onso- an
# onso to shisei - an1
# token -
# token - sun7
# pinyin- sun
# shisei- 7
# onso-
# onso to shisei - 7
# token -
# token - si7
# pinyin- si
# shisei- 7
# onso- ɕ
# onso to shisei - ɕ7
# results- tsʰɔ1 kiu2 tʰĩ1 kɔŋ1 senn 2 tso3 hue kiu5 tʰĩ1 kɔŋ1 4 a2 po2 pi3 2 tɕit4 ke1 kʰiu2 tsu2 piŋ5 an1 7 ɕ7
# 結果 =  tsʰɔ1 kiu2 tʰĩ1 kɔŋ1 senn 2 tso3 hue kiu5 tʰĩ1 kɔŋ1 4 a2 po2 pi3 2 tɕit4 ke1 kʰiu2 tsu2 piŋ5 an1 7 ɕ7
#   0%|                                      | 15/21911 [00:09<4:19:02,  1.41it/s]テキスト===      伊是這个歌仔戲班的小旦
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 伊是這个歌仔戲班的小旦
# API response text1: "i1 si7 tsit4 e5 kua1 a2 hi3 pan1 tik4 sio2 tuann3"
# API response text2: i1 si7 tsit4 e5 kua1 a2 hi3 pan1 tik4 sio2 tuann3
# pinyins_flat_list-  ['i1', ' ', 'si7', ' ', 'tsit4', ' ', 'e5', ' ', 'kua1', ' ', 'a2', ' ', 'hi3', ' ', 'pan1', ' ', 'tik4', ' ', 'sio2', ' ', 'tuann3']
# pinyined_text3- ['i1', ' ', 'si7', ' ', 'tsit4', ' ', 'e5', ' ', 'kua1', ' ', 'a2', ' ', 'hi3', ' ', 'pan1', ' ', 'tik4', ' ', 'sio2', ' ', 'tuann3']
# token - i1
# pinyin- i
# shisei- 1
# onso- i
# onso to shisei - i1
# token -
# token - si7
# pinyin- si
# shisei- 7
# onso- ɕ
# onso to shisei - ɕ7
# token -
# token - tsit4
# pinyin- tsit
# shisei- 4
# onso- tɕit
# onso to shisei - tɕit4
# token -
# token - e5
# pinyin- e
# shisei- 5
# onso- e
# onso to shisei - e5
# token -
# token - kua1
# pinyin- kua
# shisei- 1
# onso- kua
# onso to shisei - kua1
# token -
# token - a2
# pinyin- a
# shisei- 2
# onso- a
# onso to shisei - a2
# token -
# token - hi3
# pinyin- hi
# shisei- 3
# onso- hi
# onso to shisei - hi3
# token -
# token - pan1
# pinyin- pan
# shisei- 1
# onso-
# onso to shisei - 1
# token -
# token - tik4
# pinyin- tik
# shisei- 4
# onso- tɪk
# onso to shisei - tɪk4
# token -
# token - sio2
# pinyin- sio
# shisei- 2
# onso- ɕio
# onso to shisei - ɕio2
# token -
# token - tuann3
# pinyin- tuann
# shisei- 3
# onso-
# onso to shisei - 3
# results- i1 ɕ7 tɕit4 e5 kua1 a2 hi3 1 tɪk4 ɕio2 3
# 結果 =  i1 ɕ7 tɕit4 e5 kua1 a2 hi3 1 tɪk4 ɕio2 3
#   0%|                                      | 16/21911 [00:10<4:19:06,  1.41it/s]テキスト===      閃爍
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 閃爍
# API response text1: "siam2 sih4"
# API response text2: siam2 sih4
# pinyins_flat_list-  ['siam2', ' ', 'sih4']
# pinyined_text3- ['siam2', ' ', 'sih4']
# token - siam2
# pinyin- siam
# shisei- 2
# onso- ɕiam
# onso to shisei - ɕiam2
# token -
# token - sih4
# pinyin- sih
# shisei- 4
# onso-
# onso to shisei - 4
# results- ɕiam2 4
# 結果 =  ɕiam2 4
#   0%|                                      | 17/21911 [00:10<3:25:40,  1.77it/s]テキスト===      轉去塗州賣鴨卵矣
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 轉去塗州賣鴨卵矣
# API response text1: "tng2  khi3 thoo5 tsiu1 mai7 ah4 nn̄g1 ah4"
# API response text2: tng2  khi3 thoo5 tsiu1 mai7 ah4 nn̄g1 ah4
# pinyins_flat_list-  ['tng2', ' ', 'khi3', ' ', 'thoo5', ' ', 'tsiu1', ' ', 'mai7', ' ', 'ah4', ' ', 'nn̄g1', ' ', 'ah4', ' ']
# pinyined_text3- ['tng2', ' ', 'khi3', ' ', 'thoo5', ' ', 'tsiu1', ' ', 'mai7', ' ', 'ah4', ' ', 'nn̄g1', ' ', 'ah4', ' ']
# token - tng2
# pinyin- tng
# shisei- 2
# onso- tŋ̍
# onso to shisei - tŋ̍2
# token -
# token - khi3
# pinyin- khi
# shisei- 3
# onso- kʰi
# onso to shisei - kʰi3
# token -
# token - thoo5
# pinyin- thoo
# shisei- 5
# onso- tʰɔ
# onso to shisei - tʰɔ5
# token -
# token - tsiu1
# pinyin- tsiu
# shisei- 1
# onso- tsiu
# onso to shisei - tsiu1
# token -
# token - mai7
# pinyin- mai
# shisei- 7
# onso- mai
# onso to shisei - mai7
# token -
# token - ah4
# pinyin- ah
# shisei- 4
# onso- aʔ
# onso to shisei - aʔ4
# token -
# token - nn̄g1
# pinyin- nn̄g
# shisei- 1
# onso-
# onso to shisei - 1
# token -
# token - ah4
# pinyin- ah
# shisei- 4
# onso- aʔ
# onso to shisei - aʔ4
# token -
# results- tŋ̍2 kʰi3 tʰɔ5 tsiu1 mai7 aʔ4 1 aʔ4
# 結果 =  tŋ̍2 kʰi3 tʰɔ5 tsiu1 mai7 aʔ4 1 aʔ4
#   0%|                                      | 18/21911 [00:11<3:18:31,  1.84it/s]テキスト===      愛人仔變心 予伊十分的失志
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 愛人仔變心 予伊十分的失志
# API response text1: "ai3 jin5 a pian3 sim1  hoo i tsap4 hun7 tik4 sit4 tsi3"
# API response text2: ai3 jin5 a pian3 sim1  hoo i tsap4 hun7 tik4 sit4 tsi3
# pinyins_flat_list-  ['ai3', ' ', 'jin5', ' ', 'a', ' ', 'pian3', ' ', 'sim1', ' ', 'hoo', ' ', 'i', ' ', 'tsap4', ' ', 'hun7', ' ', 'tik4', ' ', 'sit4', ' ', 'tsi3']
# pinyined_text3- ['ai3', ' ', 'jin5', ' ', 'a', ' ', 'pian3', ' ', 'sim1', ' ', 'hoo', ' ', 'i', ' ', 'tsap4', ' ', 'hun7', ' ', 'tik4', ' ', 'sit4', ' ', 'tsi3']
# token - ai3
# pinyin- ai
# shisei- 3
# onso- ai
# onso to shisei - ai3
# token -
# token - jin5
# pinyin- jin
# shisei- 5
# onso- ʑin
# onso to shisei - ʑin5
# token -
# token - a
# token -
# token - pian3
# pinyin- pian
# shisei- 3
# onso- pɪɛn
# onso to shisei - pɪɛn3
# token -
# token - sim1
# pinyin- sim
# shisei- 1
# onso- sim
# onso to shisei - sim1
# token -
# token - hoo
# token -
# token - i
# token -
# token - tsap4
# pinyin- tsap
# shisei- 4
# onso- tsap
# onso to shisei - tsap4
# token -
# token - hun7
# pinyin- hun
# shisei- 7
# onso-
# onso to shisei - 7
# token -
# token - tik4
# pinyin- tik
# shisei- 4
# onso- tɪk
# onso to shisei - tɪk4
# token -
# token - sit4
# pinyin- sit
# shisei- 4
# onso- sit
# onso to shisei - sit4
# token -
# token - tsi3
# pinyin- tsi
# shisei- 3
# onso- t͡ɕ
# onso to shisei - t͡ɕ3
# results- ai3 ʑin5 a pɪɛn3 sim1 hoo i tsap4 7 tɪk4 sit4 t͡ɕ3
# 結果 =  ai3 ʑin5 a pɪɛn3 sim1 hoo i tsap4 7 tɪk4 sit4 t͡ɕ3
#   0%|                                      | 19/21911 [00:11<3:33:36,  1.71it/s]テキスト===      嘔紅
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 嘔紅
# API response text1: "au2 hong5"
# API response text2: au2 hong5
# pinyins_flat_list-  ['au2', ' ', 'hong5']
# pinyined_text3- ['au2', ' ', 'hong5']
# token - au2
# pinyin- au
# shisei- 2
# onso- au
# onso to shisei - au2
# token -
# token - hong5
# pinyin- hong
# shisei- 5
# onso- hɔŋ
# onso to shisei - hɔŋ5
# results- au2 hɔŋ5
# 結果 =  au2 hɔŋ5
#   0%|                                      | 20/21911 [00:12<2:58:26,  2.04it/s]テキスト===      伊看著怪怪
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 伊看著怪怪
# API response text1: "i1 khuann3 tu3 kuai3 kuai3"
# API response text2: i1 khuann3 tu3 kuai3 kuai3
# pinyins_flat_list-  ['i1', ' ', 'khuann3', ' ', 'tu3', ' ', 'kuai3', ' ', 'kuai3', ' ']
# pinyined_text3- ['i1', ' ', 'khuann3', ' ', 'tu3', ' ', 'kuai3', ' ', 'kuai3', ' ']
# token - i1
# pinyin- i
# shisei- 1
# onso- i
# onso to shisei - i1
# token -
# token - khuann3
# pinyin- khuann
# shisei- 3
# onso-
# onso to shisei - 3
# token -
# token - tu3
# pinyin- tu
# shisei- 3
# onso- tu
# onso to shisei - tu3
# token -
# token - kuai3
# pinyin- kuai
# shisei- 3
# onso- kuai
# onso to shisei - kuai3
# token -
# token - kuai3
# pinyin- kuai
# shisei- 3
# onso- kuai
# onso to shisei - kuai3
# token -
# results- i1 3 tu3 kuai3 kuai3
# 結果 =  i1 3 tu3 kuai3 kuai3
#   0%|                                      | 21/21911 [00:12<3:07:29,  1.95it/s]テキスト===      這間餐廳實在袂䆀 咱下日仔會用得𤆬阿母做伙來
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 這間餐廳實在袂䆀 咱下日仔會用得𤆬阿母做伙來
# API response text1: "tsit4 king1 tshan1 thiann1 sit4 tsai7 be7 bai  lan2 he7 jit tsu2 e7 ing7 tit4 uainn2 uainn2 a1 bu2 tso3 hue lai5"
# API response text2: tsit4 king1 tshan1 thiann1 sit4 tsai7 be7 bai  lan2 he7 jit tsu2 e7 ing7 tit4 uainn2 uainn2 a1 bu2 tso3 hue lai5
# pinyins_flat_list-  ['tsit4', ' ', 'king1', ' ', 'tshan1', ' ', 'thiann1', ' ', 'sit4', ' ', 'tsai7', ' ', 'be7', ' ', 'bai', ' ', 'lan2', ' ', 'he7', ' ', 'jit', ' ', 'tsu2', ' ', 'e7', ' ', 'ing7', ' ', 'tit4', ' ', 'uainn2', ' ', 'uainn2', ' ', 'a1', ' ', 'bu2', ' ', 'tso3', ' ', 'hue', ' ', 'lai5']
# pinyined_text3- ['tsit4', ' ', 'king1', ' ', 'tshan1', ' ', 'thiann1', ' ', 'sit4', ' ', 'tsai7', ' ', 'be7', ' ', 'bai', ' ', 'lan2', ' ', 'he7', ' ', 'jit', ' ', 'tsu2', ' ', 'e7', ' ', 'ing7', ' ', 'tit4', ' ', 'uainn2', ' ', 'uainn2', ' ', 'a1', ' ', 'bu2', ' ', 'tso3', ' ', 'hue', ' ', 'lai5']
# token - tsit4
# pinyin- tsit
# shisei- 4
# onso- tɕit
# onso to shisei - tɕit4
# token -
# token - king1
# pinyin- king
# shisei- 1
# onso- kiŋ
# onso to shisei - kiŋ1
# token -
# token - tshan1
# pinyin- tshan
# shisei- 1
# onso-
# onso to shisei - 1
# token -
# token - thiann1
# pinyin- thiann
# shisei- 1
# onso-
# onso to shisei - 1
# token -
# token - sit4
# pinyin- sit
# shisei- 4
# onso- sit
# onso to shisei - sit4
# token -
# token - tsai7
# pinyin- tsai
# shisei- 7
# onso- tsai
# onso to shisei - tsai7
# token -
# token - be7
# pinyin- be
# shisei- 7
# onso- be
# onso to shisei - be7
# token -
# token - bai
# token -
# token - lan2
# pinyin- lan
# shisei- 2
# onso-
# onso to shisei - 2
# token -
# token - he7
# pinyin- he
# shisei- 7
# onso- he
# onso to shisei - he7
# token -
# token - jit
# token -
# token - tsu2
# pinyin- tsu
# shisei- 2
# onso- tsu
# onso to shisei - tsu2
# token -
# token - e7
# pinyin- e
# shisei- 7
# onso- e
# onso to shisei - e7
# token -
# token - ing7
# pinyin- ing
# shisei- 7
# onso- iŋ
# onso to shisei - iŋ7
# token -
# token - tit4
# pinyin- tit
# shisei- 4
# onso- tit
# onso to shisei - tit4
# token -
# token - uainn2
# pinyin- uainn
# shisei- 2
# onso- uãi
# onso to shisei - uãi2
# token -
# token - uainn2
# pinyin- uainn
# shisei- 2
# onso- uãi
# onso to shisei - uãi2
# token -
# token - a1
# pinyin- a
# shisei- 1
# onso- a
# onso to shisei - a1
# token -
# token - bu2
# pinyin- bu
# shisei- 2
# onso- bu
# onso to shisei - bu2
# token -
# token - tso3
# pinyin- tso
# shisei- 3
# onso- tso
# onso to shisei - tso3
# token -
# token - hue
# token -
# token - lai5
# pinyin- lai
# shisei- 5
# onso- lai
# onso to shisei - lai5
# results- tɕit4 kiŋ1 1 1 sit4 tsai7 be7 bai 2 he7 jit tsu2 e7 iŋ7 tit4 uãi2 uãi2 a1 bu2 tso3 hue lai5
# 結果 =  tɕit4 kiŋ1 1 1 sit4 tsai7 be7 bai 2 he7 jit tsu2 e7 iŋ7 tit4 uãi2 uãi2 a1 bu2 tso3 hue lai5
#   0%|                                      | 22/21911 [00:13<4:28:07,  1.36it/s]テキスト===      肉鉤
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 肉鉤
# API response text1: "jiok kau1"
# API response text2: jiok kau1
# pinyins_flat_list-  ['jiok', ' ', 'kau1']
# pinyined_text3- ['jiok', ' ', 'kau1']
# token - jiok
# token -
# token - kau1
# pinyin- kau
# shisei- 1
# onso- kau
# onso to shisei - kau1
# results- jiok kau1
# 結果 =  jiok kau1
#   0%|                                      | 23/21911 [00:14<3:58:07,  1.53it/s]テキスト===      今仔日佇高速公路發生一件反車的意外
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 今仔日佇高速公路發生一件反車的意外
# API response text1: "kin1 a2 jit ti7 ko1 sok4 kong1 loo7 huat4 sing1 tsit4 kiann7 ping2 tshia1 tik4 i3 gua7"
# API response text2: kin1 a2 jit ti7 ko1 sok4 kong1 loo7 huat4 sing1 tsit4 kiann7 ping2 tshia1 tik4 i3 gua7
# pinyins_flat_list-  ['kin1', ' ', 'a2', ' ', 'jit', ' ', 'ti7', ' ', 'ko1', ' ', 'sok4', ' ', 'kong1', ' ', 'loo7', ' ', 'huat4', ' ', 'sing1', ' ', 'tsit4', ' ', 'kiann7', ' ', 'ping2', ' ', 'tshia1', ' ', 'tik4', ' ', 'i3', ' ', 'gua7']
# pinyined_text3- ['kin1', ' ', 'a2', ' ', 'jit', ' ', 'ti7', ' ', 'ko1', ' ', 'sok4', ' ', 'kong1', ' ', 'loo7', ' ', 'huat4', ' ', 'sing1', ' ', 'tsit4', ' ', 'kiann7', ' ', 'ping2', ' ', 'tshia1', ' ', 'tik4', ' ', 'i3', ' ', 'gua7']
# token - kin1
# pinyin- kin
# shisei- 1
# onso- kin
# onso to shisei - kin1
# token -
# token - a2
# pinyin- a
# shisei- 2
# onso- a
# onso to shisei - a2
# token -
# token - jit
# token -
# token - ti7
# pinyin- ti
# shisei- 7
# onso- ti
# onso to shisei - ti7
# token -
# token - ko1
# pinyin- ko
# shisei- 1
# onso- ko
# onso to shisei - ko1
# token -
# token - sok4
# pinyin- sok
# shisei- 4
# onso- sɔk
# onso to shisei - sɔk4
# token -
# token - kong1
# pinyin- kong
# shisei- 1
# onso- kɔŋ
# onso to shisei - kɔŋ1
# token -
# token - loo7
# pinyin- loo
# shisei- 7
# onso- lɔ
# onso to shisei - lɔ7
# token -
# token - huat4
# pinyin- huat
# shisei- 4
# onso-
# onso to shisei - 4
# token -
# token - sing1
# pinyin- sing
# shisei- 1
# onso- siŋ
# onso to shisei - siŋ1
# token -
# token - tsit4
# pinyin- tsit
# shisei- 4
# onso- tɕit
# onso to shisei - tɕit4
# token -
# token - kiann7
# pinyin- kiann
# shisei- 7
# onso-
# onso to shisei - 7
# token -
# token - ping2
# pinyin- ping
# shisei- 2
# onso- piŋ
# onso to shisei - piŋ2
# token -
# token - tshia1
# pinyin- tshia
# shisei- 1
# onso- tɕʰia
# onso to shisei - tɕʰia1
# token -
# token - tik4
# pinyin- tik
# shisei- 4
# onso- tɪk
# onso to shisei - tɪk4
# token -
# token - i3
# pinyin- i
# shisei- 3
# onso- i
# onso to shisei - i3
# token -
# token - gua7
# pinyin- gua
# shisei- 7
# onso- gua
# onso to shisei - gua7
# results- kin1 a2 jit ti7 ko1 sɔk4 kɔŋ1 lɔ7 4 siŋ1 tɕit4 7 piŋ2 tɕʰia1 tɪk4 i3 gua7
# 結果 =  kin1 a2 jit ti7 ko1 sɔk4 kɔŋ1 lɔ7 4 siŋ1 tɕit4 7 piŋ2 tɕʰia1 tɪk4 i3 gua7
#   0%|                                      | 24/21911 [00:15<3:59:20,  1.52it/s]テキスト===      海水本身就是鹹水
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 海水本身就是鹹水
# API response text1: "hai2 tsui2 pun2 sin1 to si kiam5 tsui2"
# API response text2: hai2 tsui2 pun2 sin1 to si kiam5 tsui2
# pinyins_flat_list-  ['hai2', ' ', 'tsui2', ' ', 'pun2', ' ', 'sin1', ' ', 'to', ' ', 'si', ' ', 'kiam5', ' ', 'tsui2', ' ']
# pinyined_text3- ['hai2', ' ', 'tsui2', ' ', 'pun2', ' ', 'sin1', ' ', 'to', ' ', 'si', ' ', 'kiam5', ' ', 'tsui2', ' ']
# token - hai2
# pinyin- hai
# shisei- 2
# onso- hai
# onso to shisei - hai2
# token -
# token - tsui2
# pinyin- tsui
# shisei- 2
# onso-
# onso to shisei - 2
# token -
# token - pun2
# pinyin- pun
# shisei- 2
# onso-
# onso to shisei - 2
# token -
# token - sin1
# pinyin- sin
# shisei- 1
# onso- ɕin
# onso to shisei - ɕin1
# token -
# token - to
# token -
# token - si
# token -
# token - kiam5
# pinyin- kiam
# shisei- 5
# onso-
# onso to shisei - 5
# token -
# token - tsui2
# pinyin- tsui
# shisei- 2
# onso-
# onso to shisei - 2
# token -
# results- hai2 2 2 ɕin1 to si 5 2
# 結果 =  hai2 2 2 ɕin1 to si 5 2
#   0%|                                      | 25/21911 [00:15<3:43:36,  1.63it/s]テキスト===      這種草真𠢕湠
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 這種草真𠢕湠
# API response text1: "tsit4 tsiong2 tsho2 tsin1 uainn2 uainn2 thuann3"
# API response text2: tsit4 tsiong2 tsho2 tsin1 uainn2 uainn2 thuann3
# pinyins_flat_list-  ['tsit4', ' ', 'tsiong2', ' ', 'tsho2', ' ', 'tsin1', ' ', 'uainn2', ' ', 'uainn2', ' ', 'thuann3']
# pinyined_text3- ['tsit4', ' ', 'tsiong2', ' ', 'tsho2', ' ', 'tsin1', ' ', 'uainn2', ' ', 'uainn2', ' ', 'thuann3']
# token - tsit4
# pinyin- tsit
# shisei- 4
# onso- tɕit
# onso to shisei - tɕit4
# token -
# token - tsiong2
# pinyin- tsiong
# shisei- 2
# onso- tɕɪɔŋ
# onso to shisei - tɕɪɔŋ2
# token -
# token - tsho2
# pinyin- tsho
# shisei- 2
# onso- tsʰo
# onso to shisei - tsʰo2
# token -
# token - tsin1
# pinyin- tsin
# shisei- 1
# onso- tsin
# onso to shisei - tsin1
# token -
# token - uainn2
# pinyin- uainn
# shisei- 2
# onso- uãi
# onso to shisei - uãi2
# token -
# token - uainn2
# pinyin- uainn
# shisei- 2
# onso- uãi
# onso to shisei - uãi2
# token -
# token - thuann3
# pinyin- thuann
# shisei- 3
# onso-
# onso to shisei - 3
# results- tɕit4 tɕɪɔŋ2 tsʰo2 tsin1 uãi2 uãi2 3
# 結果 =  tɕit4 tɕɪɔŋ2 tsʰo2 tsin1 uãi2 uãi2 3
#   0%|                                      | 26/21911 [00:16<3:44:06,  1.63it/s]テキスト===      伊毋但共人罵 甚至閣出手拍人
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 伊毋但共人罵 甚至閣出手拍人
# API response text1: "i1 m̄ na7 kiong7 lang5 me  sim7 tsi3 koh4 tshut4 tshiu2 phik4 lang5"
# API response text2: i1 m̄ na7 kiong7 lang5 me  sim7 tsi3 koh4 tshut4 tshiu2 phik4 lang5
# pinyins_flat_list-  ['i1', ' ', 'm̄', ' ', 'na7', ' ', 'kiong7', ' ', 'lang5', ' ', 'me', ' ', 'sim7', ' ', 'tsi3', ' ', 'koh4', ' ', 'tshut4', ' ', 'tshiu2', ' ', 'phik4', ' ', 'lang5', ' ']
# pinyined_text3- ['i1', ' ', 'm̄', ' ', 'na7', ' ', 'kiong7', ' ', 'lang5', ' ', 'me', ' ', 'sim7', ' ', 'tsi3', ' ', 'koh4', ' ', 'tshut4', ' ', 'tshiu2', ' ', 'phik4', ' ', 'lang5', ' ']
# token - i1
# pinyin- i
# shisei- 1
# onso- i
# onso to shisei - i1
# token -
# token - m̄
# token -
# token - na7
# pinyin- na
# shisei- 7
# onso- na
# onso to shisei - na7
# token -
# token - kiong7
# pinyin- kiong
# shisei- 7
# onso- kɪɔŋ
# onso to shisei - kɪɔŋ7
# token -
# token - lang5
# pinyin- lang
# shisei- 5
# onso-
# onso to shisei - 5
# token -
# token - me
# token -
# token - sim7
# pinyin- sim
# shisei- 7
# onso- sim
# onso to shisei - sim7
# token -
# token - tsi3
# pinyin- tsi
# shisei- 3
# onso- t͡ɕ
# onso to shisei - t͡ɕ3
# token -
# token - koh4
# pinyin- koh
# shisei- 4
# onso-
# onso to shisei - 4
# token -
# token - tshut4
# pinyin- tshut
# shisei- 4
# onso-
# onso to shisei - 4
# token -
# token - tshiu2
# pinyin- tshiu
# shisei- 2
# onso- tɕʰiu
# onso to shisei - tɕʰiu2
# token -
# token - phik4
# pinyin- phik
# shisei- 4
# onso- pʰɪk
# onso to shisei - pʰɪk4
# token -
# token - lang5
# pinyin- lang
# shisei- 5
# onso-
# onso to shisei - 5
# token -
# results- i1 m̄ na7 kɪɔŋ7 5 me sim7 t͡ɕ3 4 4 tɕʰiu2 pʰɪk4 5
# 結果 =  i1 m̄ na7 kɪɔŋ7 5 me sim7 t͡ɕ3 4 4 tɕʰiu2 pʰɪk4 5
# i1 m̄ na7 kɪɔŋ7 5 me sim7 t͡ɕ3 4 4 tɕʰiu2 pʰɪk4 5
# Character '̄' not found in the vocabulary. Discarding it.
#   0%|                                      | 27/21911 [00:17<4:01:32,  1.51it/s]テキスト===      了工閣蝕本
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 了工閣蝕本
# API response text1: "liau2 kang1 koh4 sih4 pun2"
# API response text2: liau2 kang1 koh4 sih4 pun2
# pinyins_flat_list-  ['liau2', ' ', 'kang1', ' ', 'koh4', ' ', 'sih4', ' ', 'pun2']
# pinyined_text3- ['liau2', ' ', 'kang1', ' ', 'koh4', ' ', 'sih4', ' ', 'pun2']
# token - liau2
# pinyin- liau
# shisei- 2
# onso- lɪaʊ
# onso to shisei - lɪaʊ2
# token -
# token - kang1
# pinyin- kang
# shisei- 1
# onso-
# onso to shisei - 1
# token -
# token - koh4
# pinyin- koh
# shisei- 4
# onso-
# onso to shisei - 4
# token -
# token - sih4
# pinyin- sih
# shisei- 4
# onso-
# onso to shisei - 4
# token -
# token - pun2
# pinyin- pun
# shisei- 2
# onso-
# onso to shisei - 2
# results- lɪaʊ2 1 4 4 2
# 結果 =  lɪaʊ2 1 4 4 2
#   0%|                                      | 28/21911 [00:17<3:35:03,  1.70it/s]テキスト===      伊腳數袂䆀 有代誌攏伊咧出頭
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 伊腳數袂䆀 有代誌攏伊咧出頭
# API response text1: "i1 kioh4 siau3 be7 bai  u7 tai7 tsi3 long2 i1 teh4 tshut4 thau5"
# API response text2: i1 kioh4 siau3 be7 bai  u7 tai7 tsi3 long2 i1 teh4 tshut4 thau5
# pinyins_flat_list-  ['i1', ' ', 'kioh4', ' ', 'siau3', ' ', 'be7', ' ', 'bai', ' ', 'u7', ' ', 'tai7', ' ', 'tsi3', ' ', 'long2', ' ', 'i1', ' ', 'teh4', ' ', 'tshut4', ' ', 'thau5']
# pinyined_text3- ['i1', ' ', 'kioh4', ' ', 'siau3', ' ', 'be7', ' ', 'bai', ' ', 'u7', ' ', 'tai7', ' ', 'tsi3', ' ', 'long2', ' ', 'i1', ' ', 'teh4', ' ', 'tshut4', ' ', 'thau5']
# token - i1
# pinyin- i
# shisei- 1
# onso- i
# onso to shisei - i1
# token -
# token - kioh4
# pinyin- kioh
# shisei- 4
# onso- kɪəʔ
# onso to shisei - kɪəʔ4
# token -
# token - siau3
# pinyin- siau
# shisei- 3
# onso- ɕɪaʊ
# onso to shisei - ɕɪaʊ3
# token -
# token - be7
# pinyin- be
# shisei- 7
# onso- be
# onso to shisei - be7
# token -
# token - bai
# token -
# token - u7
# pinyin- u
# shisei- 7
# onso- u
# onso to shisei - u7
# token -
# token - tai7
# pinyin- tai
# shisei- 7
# onso- tai
# onso to shisei - tai7
# token -
# token - tsi3
# pinyin- tsi
# shisei- 3
# onso- t͡ɕ
# onso to shisei - t͡ɕ3
# token -
# token - long2
# pinyin- long
# shisei- 2
# onso- lɔŋ
# onso to shisei - lɔŋ2
# token -
# token - i1
# pinyin- i
# shisei- 1
# onso- i
# onso to shisei - i1
# token -
# token - teh4
# pinyin- teh
# shisei- 4
# onso-
# onso to shisei - 4
# token -
# token - tshut4
# pinyin- tshut
# shisei- 4
# onso-
# onso to shisei - 4
# token -
# token - thau5
# pinyin- thau
# shisei- 5
# onso- tʰau
# onso to shisei - tʰau5
# results- i1 kɪəʔ4 ɕɪaʊ3 be7 bai u7 tai7 t͡ɕ3 lɔŋ2 i1 4 4 tʰau5
# 結果 =  i1 kɪəʔ4 ɕɪaʊ3 be7 bai u7 tai7 t͡ɕ3 lɔŋ2 i1 4 4 tʰau5
#   0%|                                      | 29/21911 [00:18<3:38:09,  1.67it/s]テキスト===      竹筍
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 竹筍
# API response text1: "tik4 sun2"
# API response text2: tik4 sun2
# pinyins_flat_list-  ['tik4', ' ', 'sun2']
# pinyined_text3- ['tik4', ' ', 'sun2']
# token - tik4
# pinyin- tik
# shisei- 4
# onso- tɪk
# onso to shisei - tɪk4
# token -
# token - sun2
# pinyin- sun
# shisei- 2
# onso-
# onso to shisei - 2
# results- tɪk4 2
# 結果 =  tɪk4 2
#   0%|                                      | 30/21911 [00:18<3:11:29,  1.90it/s]テキスト===      眷屬
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 眷屬
# API response text1: "kuan3 siok4"
# API response text2: kuan3 siok4
# pinyins_flat_list-  ['kuan3', ' ', 'siok4']
# pinyined_text3- ['kuan3', ' ', 'siok4']
# token - kuan3
# pinyin- kuan
# shisei- 3
# ...
# token -
# token - kiong7
# pinyin- kiong
# shisei- 7
# onso- kɪɔŋ
# onso to shisei - kɪɔŋ7
# token -
# token - lang5
# pinyin- lang
# shisei- 5
# onso-
# onso to shisei - 5
# token -
# token - e1
# pinyin- e
# shisei- 1
# onso- e
# onso to shisei - e1
# token -
# token - tu3
# pinyin- tu
# shisei- 3
# onso- tu
# onso to shisei - tu3
# token -
# token - pun2
# pinyin- pun
# shisei- 2
# onso-
# onso to shisei - 2
# token -
# token - tsiann5
# pinyin- tsiann
# shisei- 5
# onso- tɕiã
# onso to shisei - tɕiã5
# token -
# token - tsiu7
# pinyin- tsiu
# shisei- 7
# onso- tsiu
# onso to shisei - tsiu7
# token -
# token - ai3
# pinyin- ai
# shisei- 3
# onso- ai
# onso to shisei - ai3
# token -
# token - theh4
# pinyin- theh
# shisei- 4
# onso-
# onso to shisei - 4
# token -
# token - kua2
# pinyin- kua
# shisei- 2
# onso- kua
# onso to shisei - kua2
# token -
# token - tsinn5
# pinyin- tsinn
# shisei- 5
# onso- tsĩ
# onso to shisei - tsĩ5
# token -
# token - kiong7
# pinyin- kiong
# shisei- 7
# onso- kɪɔŋ
# onso to shisei - kɪɔŋ7
# token -
# token - lang5
# pinyin- lang
# shisei- 5
# onso-
# onso to shisei - 5
# token -
# token - hok4
# pinyin- hok
# shisei- 4
# onso- hɔk
# onso to shisei - hɔk4
# token -
# token - iok4
# pinyin- iok
# shisei- 4
# onso- iɔk
# onso to shisei - iɔk4
# results- li2 sai2 tɕʰia1 kɪɔŋ7 5 e1 tu3 2 tɕiã5 tsiu7 ai3 4 kua2 tsĩ5 kɪɔŋ7 5 hɔk4 iɔk4
# 結果 =  li2 sai2 tɕʰia1 kɪɔŋ7 5 e1 tu3 2 tɕiã5 tsiu7 ai3 4 kua2 tsĩ5 kɪɔŋ7 5 hɔk4 iɔk4
#   6%|██                                  | 1228/21911 [12:35<3:00:49,  1.91it/s]テキスト===      海軍
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 海軍
# API response text1: "hai2 kun1"
# API response text2: hai2 kun1
# pinyins_flat_list-  ['hai2', ' ', 'kun1']
# pinyined_text3- ['hai2', ' ', 'kun1']
# token - hai2
# pinyin- hai
# shisei- 2
# onso- hai
# onso to shisei - hai2
# token -
# token - kun1
# pinyin- kun
# shisei- 1
# onso-
# onso to shisei - 1
# results- hai2 1
# 結果 =  hai2 1
#   6%|██                                  | 1229/21911 [12:35<2:41:07,  2.14it/s]テキスト===      今仔日親情族孫攏來矣 阿媽足歡喜的
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 今仔日親情族孫攏來矣 阿媽足歡喜的
# API response text1: "kin1 a2 jit tshin1 tsing5 tsok4 sun1 long2 lai5 ah4  a1 ma2 tsiok4 huann1 hi2 tik4"
# API response text2: kin1 a2 jit tshin1 tsing5 tsok4 sun1 long2 lai5 ah4  a1 ma2 tsiok4 huann1 hi2 tik4
# pinyins_flat_list-  ['kin1', ' ', 'a2', ' ', 'jit', ' ', 'tshin1', ' ', 'tsing5', ' ', 'tsok4', ' ', 'sun1', ' ', 'long2', ' ', 'lai5', ' ', 'ah4', ' ', 'a1', ' ', 'ma2', ' ', 'tsiok4', ' ', 'huann1', ' ', 'hi2', ' ', 'tik4']
# pinyined_text3- ['kin1', ' ', 'a2', ' ', 'jit', ' ', 'tshin1', ' ', 'tsing5', ' ', 'tsok4', ' ', 'sun1', ' ', 'long2', ' ', 'lai5', ' ', 'ah4', ' ', 'a1', ' ', 'ma2', ' ', 'tsiok4', ' ', 'huann1', ' ', 'hi2', ' ', 'tik4']
# token - kin1
# pinyin- kin
# shisei- 1
# onso- kin
# onso to shisei - kin1
# token -
# token - a2
# pinyin- a
# shisei- 2
# onso- a
# onso to shisei - a2
# token -
# token - jit
# token -
# token - tshin1
# pinyin- tshin
# shisei- 1
# onso- tɕʰin
# onso to shisei - tɕʰin1
# token -
# token - tsing5
# pinyin- tsing
# shisei- 5
# onso- tsiŋ
# onso to shisei - tsiŋ5
# token -
# token - tsok4
# pinyin- tsok
# shisei- 4
# onso- tsɔk
# onso to shisei - tsɔk4
# token -
# token - sun1
# pinyin- sun
# shisei- 1
# onso-
# onso to shisei - 1
# token -
# token - long2
# pinyin- long
# shisei- 2
# onso- lɔŋ
# onso to shisei - lɔŋ2
# token -
# token - lai5
# pinyin- lai
# shisei- 5
# onso- lai
# onso to shisei - lai5
# token -
# token - ah4
# pinyin- ah
# shisei- 4
# onso- aʔ
# onso to shisei - aʔ4
# token -
# token - a1
# pinyin- a
# shisei- 1
# onso- a
# onso to shisei - a1
# token -
# token - ma2
# pinyin- ma
# shisei- 2
# onso- ma
# onso to shisei - ma2
# token -
# token - tsiok4
# pinyin- tsiok
# shisei- 4
# onso- tɕiɔk
# onso to shisei - tɕiɔk4
# token -
# token - huann1
# pinyin- huann
# shisei- 1
# onso-
# onso to shisei - 1
# token -
# token - hi2
# pinyin- hi
# shisei- 2
# onso- hi
# onso to shisei - hi2
# token -
# token - tik4
# pinyin- tik
# shisei- 4
# onso- tɪk
# onso to shisei - tɪk4
# results- kin1 a2 jit tɕʰin1 tsiŋ5 tsɔk4 1 lɔŋ2 lai5 aʔ4 a1 ma2 tɕiɔk4 1 hi2 tɪk4
# 結果 =  kin1 a2 jit tɕʰin1 tsiŋ5 tsɔk4 1 lɔŋ2 lai5 aʔ4 a1 ma2 tɕiɔk4 1 hi2 tɪk4
#   6%|██                                  | 1230/21911 [12:36<2:56:58,  1.95it/s]テキスト===      伊是一个半路師 你敢放心共工課交予伊做
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 伊是一个半路師 你敢放心共工課交予伊做
# API response text1: "i1 si7 tsit4 e5 puann3 loo7 sai1  li2 kann2 hong3 sim1 kiong7 khang1 khue3 kiau1 hoo i tso"
# API response text2: i1 si7 tsit4 e5 puann3 loo7 sai1  li2 kann2 hong3 sim1 kiong7 khang1 khue3 kiau1 hoo i tso
# pinyins_flat_list-  ['i1', ' ', 'si7', ' ', 'tsit4', ' ', 'e5', ' ', 'puann3', ' ', 'loo7', ' ', 'sai1', ' ', 'li2', ' ', 'kann2', ' ', 'hong3', ' ', 'sim1', ' ', 'kiong7', ' ', 'khang1', ' ', 'khue3', ' ', 'kiau1', ' ', 'hoo', ' ', 'i', ' ', 'tso']
# pinyined_text3- ['i1', ' ', 'si7', ' ', 'tsit4', ' ', 'e5', ' ', 'puann3', ' ', 'loo7', ' ', 'sai1', ' ', 'li2', ' ', 'kann2', ' ', 'hong3', ' ', 'sim1', ' ', 'kiong7', ' ', 'khang1', ' ', 'khue3', ' ', 'kiau1', ' ', 'hoo', ' ', 'i', ' ', 'tso']
# token - i1
# pinyin- i
# shisei- 1
# onso- i
# onso to shisei - i1
# token -
# token - si7
# pinyin- si
# shisei- 7
# onso- ɕ
# onso to shisei - ɕ7
# token -
# token - tsit4
# pinyin- tsit
# shisei- 4
# onso- tɕit
# onso to shisei - tɕit4
# token -
# token - e5
# pinyin- e
# shisei- 5
# onso- e
# onso to shisei - e5
# token -
# token - puann3
# pinyin- puann
# shisei- 3
# onso-
# onso to shisei - 3
# token -
# token - loo7
# pinyin- loo
# shisei- 7
# onso- lɔ
# onso to shisei - lɔ7
# token -
# token - sai1
# pinyin- sai
# shisei- 1
# onso- sai
# onso to shisei - sai1
# token -
# token - li2
# pinyin- li
# shisei- 2
# onso- li
# onso to shisei - li2
# token -
# token - kann2
# pinyin- kann
# shisei- 2
# onso- kã
# onso to shisei - kã2
# token -
# token - hong3
# pinyin- hong
# shisei- 3
# onso- hɔŋ
# onso to shisei - hɔŋ3
# token -
# token - sim1
# pinyin- sim
# shisei- 1
# onso- sim
# onso to shisei - sim1
# token -
# token - kiong7
# pinyin- kiong
# shisei- 7
# onso- kɪɔŋ
# onso to shisei - kɪɔŋ7
# token -
# token - khang1
# pinyin- khang
# shisei- 1
# onso-
# onso to shisei - 1
# token -
# token - khue3
# pinyin- khue
# shisei- 3
# onso- kʰue
# onso to shisei - kʰue3
# token -
# token - kiau1
# pinyin- kiau
# shisei- 1
# onso- kɪaʊ
# onso to shisei - kɪaʊ1
# token -
# token - hoo
# token -
# token - i
# token -
# token - tso
# results- i1 ɕ7 tɕit4 e5 3 lɔ7 sai1 li2 kã2 hɔŋ3 sim1 kɪɔŋ7 1 kʰue3 kɪaʊ1 hoo i tso
# 結果 =  i1 ɕ7 tɕit4 e5 3 lɔ7 sai1 li2 kã2 hɔŋ3 sim1 kɪɔŋ7 1 kʰue3 kɪaʊ1 hoo i tso
#   6%|██                                  | 1231/21911 [12:37<4:02:30,  1.42it/s]テキスト===      變空
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 變空
# API response text1: "pinn3 khang1"
# API response text2: pinn3 khang1
# pinyins_flat_list-  ['pinn3', ' ', 'khang1']
# pinyined_text3- ['pinn3', ' ', 'khang1']
# token - pinn3
# pinyin- pinn
# shisei- 3
# onso- pĩ
# onso to shisei - pĩ3
# token -
# token - khang1
# pinyin- khang
# shisei- 1
# onso-
# onso to shisei - 1
# results- pĩ3 1
# 結果 =  pĩ3 1
#   6%|██                                  | 1232/21911 [12:37<3:18:06,  1.74it/s]テキスト===      伊串講攏講涼腔 免聽啦
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 伊串講攏講涼腔 免聽啦
# API response text1: "i1 tshuan3 kong2 long2 kong2 liang5 khiang1  bian2 thing3 lah4"
# API response text2: i1 tshuan3 kong2 long2 kong2 liang5 khiang1  bian2 thing3 lah4
# pinyins_flat_list-  ['i1', ' ', 'tshuan3', ' ', 'kong2', ' ', 'long2', ' ', 'kong2', ' ', 'liang5', ' ', 'khiang1', ' ', 'bian2', ' ', 'thing3', ' ', 'lah4']
# pinyined_text3- ['i1', ' ', 'tshuan3', ' ', 'kong2', ' ', 'long2', ' ', 'kong2', ' ', 'liang5', ' ', 'khiang1', ' ', 'bian2', ' ', 'thing3', ' ', 'lah4']
# token - i1
# pinyin- i
# shisei- 1
# onso- i
# onso to shisei - i1
# token -
# token - tshuan3
# pinyin- tshuan
# shisei- 3
# onso- tsʰuan
# onso to shisei - tsʰuan3
# token -
# token - kong2
# pinyin- kong
# shisei- 2
# onso- kɔŋ
# onso to shisei - kɔŋ2
# token -
# token - long2
# pinyin- long
# shisei- 2
# onso- lɔŋ
# onso to shisei - lɔŋ2
# token -
# token - kong2
# pinyin- kong
# shisei- 2
# onso- kɔŋ
# onso to shisei - kɔŋ2
# token -
# token - liang5
# pinyin- liang
# shisei- 5
# onso-
# onso to shisei - 5
# token -
# token - khiang1
# pinyin- khiang
# shisei- 1
# onso-
# onso to shisei - 1
# token -
# token - bian2
# pinyin- bian
# shisei- 2
# onso- bɪɛn
# onso to shisei - bɪɛn2
# token -
# token - thing3
# pinyin- thing
# shisei- 3
# onso- tʰiŋ
# onso to shisei - tʰiŋ3
# token -
# token - lah4
# pinyin- lah
# shisei- 4
# onso- laʔ
# onso to shisei - laʔ4
# results- i1 tsʰuan3 kɔŋ2 lɔŋ2 kɔŋ2 5 1 bɪɛn2 tʰiŋ3 laʔ4
# 結果 =  i1 tsʰuan3 kɔŋ2 lɔŋ2 kɔŋ2 5 1 bɪɛn2 tʰiŋ3 laʔ4
#   6%|██                                  | 1233/21911 [12:38<3:17:55,  1.74it/s]テキスト===      我欲出國的時 真濟朋友攏來相送
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 我欲出國的時 真濟朋友攏來相送
# API response text1: "gua2 beh4 tshut4 kok4 tik4 si5  tsin1 tse ping5 iu2 long2 lai5 sio1 sang3"
# API response text2: gua2 beh4 tshut4 kok4 tik4 si5  tsin1 tse ping5 iu2 long2 lai5 sio1 sang3
# pinyins_flat_list-  ['gua2', ' ', 'beh4', ' ', 'tshut4', ' ', 'kok4', ' ', 'tik4', ' ', 'si5', ' ', 'tsin1', ' ', 'tse', ' ', 'ping5', ' ', 'iu2', ' ', 'long2', ' ', 'lai5', ' ', 'sio1', ' ', 'sang3']
# pinyined_text3- ['gua2', ' ', 'beh4', ' ', 'tshut4', ' ', 'kok4', ' ', 'tik4', ' ', 'si5', ' ', 'tsin1', ' ', 'tse', ' ', 'ping5', ' ', 'iu2', ' ', 'long2', ' ', 'lai5', ' ', 'sio1', ' ', 'sang3']
# token - gua2
# pinyin- gua
# shisei- 2
# onso- gua
# onso to shisei - gua2
# token -
# token - beh4
# pinyin- beh
# shisei- 4
# onso-
# onso to shisei - 4
# token -
# token - tshut4
# pinyin- tshut
# shisei- 4
# onso-
# onso to shisei - 4
# token -
# token - kok4
# pinyin- kok
# shisei- 4
# onso- kɔk
# onso to shisei - kɔk4
# token -
# token - tik4
# pinyin- tik
# shisei- 4
# onso- tɪk
# onso to shisei - tɪk4
# token -
# token - si5
# pinyin- si
# shisei- 5
# onso- ɕ
# onso to shisei - ɕ5
# token -
# token - tsin1
# pinyin- tsin
# shisei- 1
# onso- tsin
# onso to shisei - tsin1
# token -
# token - tse
# token -
# token - ping5
# pinyin- ping
# shisei- 5
# onso- piŋ
# onso to shisei - piŋ5
# token -
# token - iu2
# pinyin- iu
# shisei- 2
# onso- iu
# onso to shisei - iu2
# token -
# token - long2
# pinyin- long
# shisei- 2
# onso- lɔŋ
# onso to shisei - lɔŋ2
# token -
# token - lai5
# pinyin- lai
# shisei- 5
# onso- lai
# onso to shisei - lai5
# token -
# token - sio1
# pinyin- sio
# shisei- 1
# onso- ɕio
# onso to shisei - ɕio1
# token -
# token - sang3
# pinyin- sang
# shisei- 3
# onso-
# onso to shisei - 3
# results- gua2 4 4 kɔk4 tɪk4 ɕ5 tsin1 tse piŋ5 iu2 lɔŋ2 lai5 ɕio1 3
# 結果 =  gua2 4 4 kɔk4 tɪk4 ɕ5 tsin1 tse piŋ5 iu2 lɔŋ2 lai5 ɕio1 3
#   6%|██                                  | 1234/21911 [12:39<3:42:30,  1.55it/s]テキスト===      我今仔日是專工欲來佮你相辭的
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 我今仔日是專工欲來佮你相辭的
# API response text1: "gua2 kin1 a2 jit si7 tsuan1 kang1 beh4 lai5 kap4 li2 sio1 si5 tik4"
# API response text2: gua2 kin1 a2 jit si7 tsuan1 kang1 beh4 lai5 kap4 li2 sio1 si5 tik4
# pinyins_flat_list-  ['gua2', ' ', 'kin1', ' ', 'a2', ' ', 'jit', ' ', 'si7', ' ', 'tsuan1', ' ', 'kang1', ' ', 'beh4', ' ', 'lai5', ' ', 'kap4', ' ', 'li2', ' ', 'sio1', ' ', 'si5', ' ', 'tik4']
# pinyined_text3- ['gua2', ' ', 'kin1', ' ', 'a2', ' ', 'jit', ' ', 'si7', ' ', 'tsuan1', ' ', 'kang1', ' ', 'beh4', ' ', 'lai5', ' ', 'kap4', ' ', 'li2', ' ', 'sio1', ' ', 'si5', ' ', 'tik4']
# token - gua2
# pinyin- gua
# shisei- 2
# onso- gua
# onso to shisei - gua2
# token -
# token - kin1
# pinyin- kin
# shisei- 1
# onso- kin
# onso to shisei - kin1
# token -
# token - a2
# pinyin- a
# shisei- 2
# onso- a
# onso to shisei - a2
# token -
# token - jit
# token -
# token - si7
# pinyin- si
# shisei- 7
# onso- ɕ
# onso to shisei - ɕ7
# token -
# token - tsuan1
# pinyin- tsuan
# shisei- 1
# onso- tɕuan
# onso to shisei - tɕuan1
# token -
# token - kang1
# pinyin- kang
# shisei- 1
# onso-
# onso to shisei - 1
# token -
# token - beh4
# pinyin- beh
# shisei- 4
# onso-
# onso to shisei - 4
# token -
# token - lai5
# pinyin- lai
# shisei- 5
# onso- lai
# onso to shisei - lai5
# token -
# token - kap4
# pinyin- kap
# shisei- 4
# onso- kap
# onso to shisei - kap4
# token -
# token - li2
# pinyin- li
# shisei- 2
# onso- li
# onso to shisei - li2
# token -
# token - sio1
# pinyin- sio
# shisei- 1
# onso- ɕio
# onso to shisei - ɕio1
# token -
# token - si5
# pinyin- si
# shisei- 5
# onso- ɕ
# onso to shisei - ɕ5
# token -
# token - tik4
# pinyin- tik
# shisei- 4
# onso- tɪk
# onso to shisei - tɪk4
# results- gua2 kin1 a2 jit ɕ7 tɕuan1 1 4 lai5 kap4 li2 ɕio1 ɕ5 tɪk4
# 結果 =  gua2 kin1 a2 jit ɕ7 tɕuan1 1 4 lai5 kap4 li2 ɕio1 ɕ5 tɪk4
#   6%|██                                  | 1235/21911 [12:39<3:42:19,  1.55it/s]テキスト===      落台的時愛共觀眾行禮
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 落台的時愛共觀眾行禮
# API response text1: "loh4 tai5 tik4 si5 ai3 kiong7 kuan1 tsiong3 kiann5 le2"
# API response text2: loh4 tai5 tik4 si5 ai3 kiong7 kuan1 tsiong3 kiann5 le2
# pinyins_flat_list-  ['loh4', ' ', 'tai5', ' ', 'tik4', ' ', 'si5', ' ', 'ai3', ' ', 'kiong7', ' ', 'kuan1', ' ', 'tsiong3', ' ', 'kiann5', ' ', 'le2']
# pinyined_text3- ['loh4', ' ', 'tai5', ' ', 'tik4', ' ', 'si5', ' ', 'ai3', ' ', 'kiong7', ' ', 'kuan1', ' ', 'tsiong3', ' ', 'kiann5', ' ', 'le2']
# token - loh4
# pinyin- loh
# shisei- 4
# onso-
# onso to shisei - 4
# token -
# token - tai5
# pinyin- tai
# shisei- 5
# onso- tai
# onso to shisei - tai5
# token -
# token - tik4
# pinyin- tik
# shisei- 4
# onso- tɪk
# onso to shisei - tɪk4
# token -
# token - si5
# pinyin- si
# shisei- 5
# onso- ɕ
# onso to shisei - ɕ5
# token -
# token - ai3
# pinyin- ai
# shisei- 3
# onso- ai
# onso to shisei - ai3
# token -
# token - kiong7
# pinyin- kiong
# shisei- 7
# onso- kɪɔŋ
# onso to shisei - kɪɔŋ7
# token -
# token - kuan1
# pinyin- kuan
# shisei- 1
# onso- kuan
# onso to shisei - kuan1
# token -
# token - tsiong3
# pinyin- tsiong
# shisei- 3
# onso- tɕɪɔŋ
# onso to shisei - tɕɪɔŋ3
# token -
# token - kiann5
# pinyin- kiann
# shisei- 5
# onso-
# onso to shisei - 5
# token -
# token - le2
# pinyin- le
# shisei- 2
# onso- le
# onso to shisei - le2
# results- 4 tai5 tɪk4 ɕ5 ai3 kɪɔŋ7 kuan1 tɕɪɔŋ3 5 le2
# 結果 =  4 tai5 tɪk4 ɕ5 ai3 kɪɔŋ7 kuan1 tɕɪɔŋ3 5 le2
#   6%|██                                  | 1236/21911 [12:40<3:37:17,  1.59it/s]テキスト===      脾土袂合
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 脾土袂合
# API response text1: "pi5 thoo2 be hah"
# API response text2: pi5 thoo2 be hah
# pinyins_flat_list-  ['pi5', ' ', 'thoo2', ' ', 'be', ' ', 'hah']
# pinyined_text3- ['pi5', ' ', 'thoo2', ' ', 'be', ' ', 'hah']
# token - pi5
# pinyin- pi
# shisei- 5
# onso- pi
# onso to shisei - pi5
# token -
# token - thoo2
# pinyin- thoo
# shisei- 2
# onso- tʰɔ
# onso to shisei - tʰɔ2
# token -
# token - be
# token -
# token - hah
# results- pi5 tʰɔ2 be hah
# 結果 =  pi5 tʰɔ2 be hah
#   6%|██                                  | 1237/21911 [12:40<3:16:12,  1.76it/s]テキスト===      警察掠著的是人頭 毋是真正的頭家
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 警察掠著的是人頭 毋是真正的頭家
# API response text1: "king2 tshat4 liok tu3 tik4 si7 lang5 thau5  m̄ si tsin1 tsiann3 tik4 thau5 ke1"
# API response text2: king2 tshat4 liok tu3 tik4 si7 lang5 thau5  m̄ si tsin1 tsiann3 tik4 thau5 ke1
# pinyins_flat_list-  ['king2', ' ', 'tshat4', ' ', 'liok', ' ', 'tu3', ' ', 'tik4', ' ', 'si7', ' ', 'lang5', ' ', 'thau5', ' ', 'm̄', ' ', 'si', ' ', 'tsin1', ' ', 'tsiann3', ' ', 'tik4', ' ', 'thau5', ' ', 'ke1']
# pinyined_text3- ['king2', ' ', 'tshat4', ' ', 'liok', ' ', 'tu3', ' ', 'tik4', ' ', 'si7', ' ', 'lang5', ' ', 'thau5', ' ', 'm̄', ' ', 'si', ' ', 'tsin1', ' ', 'tsiann3', ' ', 'tik4', ' ', 'thau5', ' ', 'ke1']
# token - king2
# pinyin- king
# shisei- 2
# onso- kiŋ
# onso to shisei - kiŋ2
# token -
# token - tshat4
# pinyin- tshat
# shisei- 4
# onso- tsʰat
# onso to shisei - tsʰat4
# token -
# token - liok
# token -
# token - tu3
# pinyin- tu
# shisei- 3
# onso- tu
# onso to shisei - tu3
# token -
# token - tik4
# pinyin- tik
# shisei- 4
# onso- tɪk
# onso to shisei - tɪk4
# token -
# token - si7
# pinyin- si
# shisei- 7
# onso- ɕ
# onso to shisei - ɕ7
# token -
# token - lang5
# pinyin- lang
# shisei- 5
# onso-
# onso to shisei - 5
# token -
# token - thau5
# pinyin- thau
# shisei- 5
# onso- tʰau
# onso to shisei - tʰau5
# token -
# token - m̄
# token -
# token - si
# token -
# token - tsin1
# pinyin- tsin
# shisei- 1
# onso- tsin
# onso to shisei - tsin1
# token -
# token - tsiann3
# pinyin- tsiann
# shisei- 3
# onso- tɕiã
# onso to shisei - tɕiã3
# token -
# token - tik4
# pinyin- tik
# shisei- 4
# onso- tɪk
# onso to shisei - tɪk4
# token -
# token - thau5
# pinyin- thau
# shisei- 5
# onso- tʰau
# onso to shisei - tʰau5
# token -
# token - ke1
# pinyin- ke
# shisei- 1
# onso- ke
# onso to shisei - ke1
# results- kiŋ2 tsʰat4 liok tu3 tɪk4 ɕ7 5 tʰau5 m̄ si tsin1 tɕiã3 tɪk4 tʰau5 ke1
# 結果 =  kiŋ2 tsʰat4 liok tu3 tɪk4 ɕ7 5 tʰau5 m̄ si tsin1 tɕiã3 tɪk4 tʰau5 ke1
#   6%|██                                  | 1238/21911 [12:41<3:16:07,  1.76it/s]テキスト===      伊猶未講完 毋通僭話
# セパレーター===
# 分かち書きがされてnaiと思うんですけど: 伊猶未講完 毋通僭話

# %%
#tts test

#English
in_pathModel = '/home/shogo/デスクトップ/Coqui-tts-20240914/TTS/TTS/run-September-14-2024_11+38AM-dbf1a08a/best_model_400488.pth'
in_config = '/home/shogo/デスクトップ/Coqui-tts-20240914/TTS/TTS/run-September-14-2024_11+38AM-dbf1a08a/config.json'
out_path = '/home/shogo/デスクトップ/Coqui-tts-20240914/TTS/TTS/run-September-14-2024_11+38AM-dbf1a08a/speech.wav'

#taiwanese
#in_pathModel = '/home/shogo/デスクトップ/Coqui-tts-20240914/TTS/TTS/run-September-16-2024_07+20PM-9b742478/best_model.pth'
#in_config = '/home/shogo/デスクトップ/Coqui-tts-20240914/TTS/TTS/run-September-16-2024_07+20PM-9b742478/config.json'
#out_path = '/home/shogo/デスクトップ/Coqui-tts-20240914/TTS/TTS/run-September-16-2024_07+20PM-9b742478/speech.wav'

#taiwanese2
#in_pathModel = '/home/shogo/デスクトップ/Coqui-tts-20240914/TTS/TTS/run-September-19-2024_01+00AM-9b742478/best_mohdel_22470.pt'
#in_config = '/home/shogo/デスクトップ/Coqui-tts-20240914/TTS/TTS/run-September-19-2024_01+00AM-9b742478/config.json'
#out_path = '/home/shogo/デスクトップ/Coqui-tts-20240914/TTS/TTS/run-September-19-2024_01+00AM-9b742478/speech.wav'

#NOW
#in_pathModel = '/home/shogo/デスクトップ/Coqui-tts-20240914/TTS/TTS/TEST/best_model.pth'
#in_config = '/home/shogo/デスクトップ/Coqui-tts-20240914/TTS/TTS/TEST/config.json'
#out_path = '/home/shogo/デスクトップ/Coqui-tts-20240914/TTS/TTS/TEST/speech.wav'



# !tts --text "Text for TTS" --model_path {in_pathModel} --config_path {in_config} --out_path {out_path}
#!tts --text "阿英" --model_path {in_pathModel} --config_path {in_config} --out_path {out_path}

#!tts --text "阿英，好來食晝矣。" --model_path {in_pathModel} --config_path {in_config} --out_path {out_path}
#!tts --text "食晝。" --model_path {in_pathModel} --config_path {in_config} --out_path {out_path}
#!tts --text "食晝才來共伊看。" --model_path {in_pathModel} --config_path {in_config} --out_path {out_path}
